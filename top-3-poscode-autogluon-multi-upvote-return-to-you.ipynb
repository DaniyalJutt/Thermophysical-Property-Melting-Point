# %% [markdown]
# <a href="https://www.kaggle.com/code/daniyalatta/autogluon-multi-1-upvote-1-motivations?scriptVersionId=261748334" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# <div style="text-align:center; border-radius:25px 70px; padding:15px; color:#ffffff; margin:0; font-size:180%; font-family:'Quicksand', sans-serif; background:#24a695; overflow:hidden">
#   <b>
#     <h3  style="font-weight:150;color:#ffffff; font-size:120%">🚀 Your upvote can motivate me to share more useful notebooks!</h3>
#     <h4 style=" font-weight:120; color:#ffffff; font-size:100%">Rate My Notebook Design</h4>
#   </b>
# </div>

# %% [markdown]
# <!-- ================= HEADER ================= -->
# <div style="border-radius:25px 70px; padding:14px 18px; margin:0 0 18px 0;
#             font-family:'Quicksand', sans-serif; background:#24a695; overflow:hidden;">
#   <div style="text-align:center; color:#ffffff; font-size:150%; margin:0; padding:0;">
#     <b><h1 style="margin:0; color:#ffffff;">Thermophysical Property: Melting Point</h1></b>
#   </div>
# </div>
#
# <!-- ================= TABLE OF CONTENTS HEADER ================= -->
# <div style="border-radius:25px 70px; padding:10px 16px; margin:10px 0; font-family:'Quicksand', sans-serif; background:#24a695; overflow:hidden;">
#   <div style="text-align:center; color:#ffffff; font-size:140%; margin:0; padding:0;">
#     <b><h2 style="margin:0; color:#ffffff;">Table of Contents</h2></b>
#   </div>
# </div>
#
# <!-- ================= TABLE OF CONTENTS LIST ================= -->
# <div style="background:#24a695; padding:12px 16px; border-radius:16px; font-family:Inter, system-ui, 'Segoe UI', Roboto, Arial, sans-serif; margin-bottom:20px;">
#   <ol style="margin:0; font-size:18px; padding-left:22px; line-height:1.7; color:#ffffff;">
#     <li><a href="#Setup-and-Data-Loading" style="color:#ffffff; text-decoration:none;">Setup and Data Loading</a></li>
#     <li><a href="#RDKit-Feature-Generation-Function" style="color:#ffffff; text-decoration:none;">RDKit Feature Generation Functions</a></li>
#     <li><a href="#Execute-Feature-Generation" style="color:#ffffff; text-decoration:none;">Execute Feature Generation</a></li>
#     <li><a href="#AutoGluon-Training-and-Prediction" style="color:#ffffff; text-decoration:none;">AutoGluon Training and Prediction</a></li>
#     <li><a href="#Submission-File-Creation-and-Final-Timing" style="color:#ffffff; text-decoration:none;">Submission File Creation and Final Timing</a></li>
#   </ol>
# </div>

# %% [markdown]
# ![](https://www.googleapis.com/download/storage/v1/b/kaggle-forum-message-attachments/o/inbox%2F14134958%2F17b6a7f04d41676af54132813a0b64ac%2FThermal-Properties-of-matter-.webp?generation=1757037113142785&alt=media)

# %%
pip install rdkit
# Out:
# Collecting rdkit
#   Downloading rdkit-2025.3.6-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from rdkit) (1.26.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from rdkit) (11.2.1)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->rdkit) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->rdkit) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->rdkit) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->rdkit) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->rdkit) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->rdkit) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->rdkit) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->rdkit) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->rdkit) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->rdkit) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->rdkit) (2024.2.0)
# Downloading rdkit-2025.3.6-cp311-cp311-manylinux_2_28_x86_64.whl (36.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.2/36.2 MB 42.9 MB/s eta 0:00:00
# Installing collected packages: rdkit
# Successfully installed rdkit-2025.3.6
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install autogluon.tabular scikit-learn==1.5.2
# Out:
# Collecting autogluon.tabular
#   Downloading autogluon.tabular-1.4.0-py3-none-any.whl.metadata (16 kB)
# Collecting scikit-learn==1.5.2
#   Downloading scikit_learn-1.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.2) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.2) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.2) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.2) (3.6.0)
# Requirement already satisfied: pandas<2.4.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from autogluon.tabular) (2.2.3)
# Requirement already satisfied: networkx<4,>=3.0 in /usr/local/lib/python3.11/dist-packages (from autogluon.tabular) (3.5)
# Collecting autogluon.core==1.4.0 (from autogluon.tabular)
#   Downloading autogluon.core-1.4.0-py3-none-any.whl.metadata (12 kB)
# Collecting autogluon.features==1.4.0 (from autogluon.tabular)
#   Downloading autogluon.features-1.4.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: tqdm<5,>=4.38 in /usr/local/lib/python3.11/dist-packages (from autogluon.core==1.4.0->autogluon.tabular) (4.67.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from autogluon.core==1.4.0->autogluon.tabular) (2.32.4)
# Requirement already satisfied: matplotlib<3.11,>=3.7.0 in /usr/local/lib/python3.11/dist-packages (from autogluon.core==1.4.0->autogluon.tabular) (3.7.2)
# Requirement already satisfied: boto3<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from autogluon.core==1.4.0->autogluon.tabular) (1.39.1)
# Collecting autogluon.common==1.4.0 (from autogluon.core==1.4.0->autogluon.tabular)
#   Downloading autogluon.common-1.4.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pyarrow<21.0.0,>=7.0.0 in /usr/local/lib/python3.11/dist-packages (from autogluon.common==1.4.0->autogluon.core==1.4.0->autogluon.tabular) (19.0.1)
# Requirement already satisfied: psutil<7.1.0,>=5.7.3 in /usr/local/lib/python3.11/dist-packages (from autogluon.common==1.4.0->autogluon.core==1.4.0->autogluon.tabular) (7.0.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.19.5->scikit-learn==1.5.2) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.19.5->scikit-learn==1.5.2) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.19.5->scikit-learn==1.5.2) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.19.5->scikit-learn==1.5.2) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.19.5->scikit-learn==1.5.2) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.19.5->scikit-learn==1.5.2) (2.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas<2.4.0,>=2.0.0->autogluon.tabular) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<2.4.0,>=2.0.0->autogluon.tabular) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<2.4.0,>=2.0.0->autogluon.tabular) (2025.2)
# Requirement already satisfied: botocore<1.40.0,>=1.39.1 in /usr/local/lib/python3.11/dist-packages (from boto3<2,>=1.10->autogluon.core==1.4.0->autogluon.tabular) (1.39.1)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from boto3<2,>=1.10->autogluon.core==1.4.0->autogluon.tabular) (1.0.1)
# Requirement already satisfied: s3transfer<0.14.0,>=0.13.0 in /usr/local/lib/python3.11/dist-packages (from boto3<2,>=1.10->autogluon.core==1.4.0->autogluon.tabular) (0.13.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.4.0->autogluon.tabular) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.4.0->autogluon.tabular) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.4.0->autogluon.tabular) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.4.0->autogluon.tabular) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.4.0->autogluon.tabular) (25.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.4.0->autogluon.tabular) (11.2.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.4.0->autogluon.tabular) (3.0.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas<2.4.0,>=2.0.0->autogluon.tabular) (1.17.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.19.5->scikit-learn==1.5.2) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.19.5->scikit-learn==1.5.2) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.19.5->scikit-learn==1.5.2) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.19.5->scikit-learn==1.5.2) (2024.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->autogluon.core==1.4.0->autogluon.tabular) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->autogluon.core==1.4.0->autogluon.tabular) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->autogluon.core==1.4.0->autogluon.tabular) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->autogluon.core==1.4.0->autogluon.tabular) (2025.6.15)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.19.5->scikit-learn==1.5.2) (2024.2.0)
# Downloading scikit_learn-1.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 83.7 MB/s eta 0:00:00
# Downloading autogluon.tabular-1.4.0-py3-none-any.whl (487 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 487.3/487.3 kB 24.8 MB/s eta 0:00:00
# Downloading autogluon.core-1.4.0-py3-none-any.whl (225 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.1/225.1 kB 11.2 MB/s eta 0:00:00
# Downloading autogluon.features-1.4.0-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.2/64.2 kB 3.3 MB/s eta 0:00:00
# Downloading autogluon.common-1.4.0-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.0/71.0 kB 3.9 MB/s eta 0:00:00
# Installing collected packages: scikit-learn, autogluon.common, autogluon.features, autogluon.core, autogluon.tabular
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed autogluon.common-1.4.0 autogluon.core-1.4.0 autogluon.features-1.4.0 autogluon.tabular-1.4.0 scikit-learn-1.5.2

# %% [markdown]
# <!-- ================= H2 HEADER: Setup and Data Loading ================= -->
# <div style="border-radius:25px 70px; padding:14px 18px; margin:10px 0;
#             font-family:'Quicksand', sans-serif; background:#24a695; overflow:hidden;">
#   <div style="text-align:center; color:#ffffff; font-size:150%; margin:0; padding:0;">
#     <b><h2 style="margin:0; color:#ffffff;">Setup and Data Loading</h2></b>
#   </div>
# </div>
#
# <!-- ================= BADGES: Important Libraries ================= -->
# <div style="display:flex; gap:10px; flex-wrap:wrap; justify-content:center; margin:12px 0; font-family:Inter, system-ui, 'Segoe UI', Roboto, Arial, sans-serif;">
#   <span style="background:#e2e8f0; color:#0f172a; padding:6px 14px; border-radius:999px; font-size:13px; border:1px solid #cbd5e1;">time</span>
#   <span style="background:#dbeafe; color:#1e3a8a; padding:6px 14px; border-radius:999px; font-size:13px; border:1px solid #bfdbfe;">shutil</span>
#   <span style="background:#dcfce7; color:#14532d; padding:6px 14px; border-radius:999px; font-size:13px; border:1px solid #bbf7d0;">warnings</span>
#   <span style="background:#fde68a; color:#92400e; padding:6px 14px; border-radius:999px; font-size:13px; border:1px solid #fcd34d;">numpy</span>
#   <span style="background:#fcd5ce; color:#881337; padding:6px 14px; border-radius:999px; font-size:13px; border:1px solid #fda4af;">pandas</span>
#   <span style="background:#e9d5ff; color:#581c87; padding:6px 14px; border-radius:999px; font-size:13px; border:1px solid #d8b4fe;">tqdm</span>
#   <span style="background:#d1fae5; color:#065f46; padding:6px 14px; border-radius:999px; font-size:13px; border:1px solid #a7f3d0;">multiprocessing</span>
#   <span style="background:#c7d2fe; color:#3730a3; padding:6px 14px; border-radius:999px; font-size:13px; border:1px solid #a5b4fc;">rdkit</span>
#   <span style="background:#fde68a; color:#78350f; padding:6px 14px; border-radius:999px; font-size:13px; border:1px solid #fcd34d;">autogluon.tabular</span>
# </div>

# %%
import time
import shutil
import warnings
import numpy as np
import pandas as pd
from tqdm import tqdm
import multiprocessing
from rdkit import Chem
from rdkit.Chem import Descriptors
from autogluon.tabular import TabularPredictor
from rdkit.Chem.rdMolDescriptors import GetMorganFingerprintAsBitVect, GetMACCSKeysFingerprint

# Ignore all warnings to keep the output clean
warnings.filterwarnings("ignore")

# Start timing the script
start_time = time.time()

print("Loading data...")
try:
    train_df = pd.read_csv("/kaggle/input/melting-point/train.csv")
    test_df = pd.read_csv("/kaggle/input/melting-point/test.csv")
    sample_submission = pd.read_csv("/kaggle/input/melting-point/sample_submission.csv")
    print("Data loaded successfully.")
except FileNotFoundError as e:
    print(f"Error: {e}. Make sure the data is in the correct directory.")
    exit()
# Out:
# Loading data...
# Data loaded successfully.

# %% [markdown]
# <!-- ================= H2 HEADER: RDKit Feature Generation Function ================= -->
# <div style="border-radius:25px 70px; padding:14px 18px; margin:10px 0;
#             font-family:'Quicksand', sans-serif; background:#24a695; overflow:hidden;">
#   <div style="text-align:center; color:#ffffff; font-size:150%; margin:0; padding:0;">
#     <b><h2 style="margin:0; color:#ffffff;">RDKit Feature Generation Function</h2></b>
#   </div>
# </div>
#
# <!-- ================= BADGES: Important RDKit Functions ================= -->
# <div style="display:flex; gap:10px; flex-wrap:wrap; justify-content:center; margin:12px 0; font-family:Inter, system-ui, 'Segoe UI', Roboto, Arial, sans-serif;">
#   <span style="background:#e2e8f0; color:#0f172a; padding:6px 14px; border-radius:999px; font-size:13px; border:1px solid #cbd5e1;">Chem.MolFromSmiles</span>
#   <span style="background:#dbeafe; color:#1e3a8a; padding:6px 14px; border-radius:999px; font-size:13px; border:1px solid #bfdbfe;">Descriptors</span>
#   <span style="background:#dcfce7; color:#14532d; padding:6px 14px; border-radius:999px; font-size:13px; border:1px solid #bbf7d0;">GetMorganFingerprintAsBitVect</span>
#   <span style="background:#fde68a; color:#92400e; padding:6px 14px; border-radius:999px; font-size:13px; border:1px solid #fcd34d;">GetMACCSKeysFingerprint</span>
# </div>

# %%
import numpy as np
import pandas as pd
from rdkit import Chem
from rdkit.Chem import Descriptors, rdMolDescriptors, Crippen
from rdkit.Chem import AllChem
from rdkit.Chem.rdMolDescriptors import GetMorganFingerprintAsBitVect, GetMACCSKeysFingerprint
from tqdm import tqdm
import multiprocessing
import warnings
warnings.filterwarnings('ignore')

# Identify features and target
TARGET = "Tm"
ID_COL = "id"
SMILES_COL = "SMILES"

print(f"Train data shape: {train_df.shape}")
print(f"Test data shape: {test_df.shape}")

class EnhancedMolecularFeatures:
    def __init__(self):
        # No problematic imports - everything works
        pass
    
    def generate_3d_conformer(self, mol):
        """Generate 3D conformer for geometric descriptors"""
        try:
            mol = Chem.AddHs(mol)
            AllChem.EmbedMolecule(mol, randomSeed=42)
            AllChem.MMFFOptimizeMolecule(mol)
            return mol
        except:
            return None
    
    def get_3d_descriptors(self, mol_3d):
        """Calculate 3D geometric descriptors"""
        features = {}
        if mol_3d is None:
            return {f'3D_{key}': 0 for key in [
                'PMI1', 'PMI2', 'PMI3', 'NPR1', 'NPR2', 'RadiusOfGyration',
                'InertialShapeFactor', 'Eccentricity', 'Asphericity', 'SpherocityIndex'
            ]}
        
        try:
            features['3D_PMI1'] = rdMolDescriptors.PMI1(mol_3d)
            features['3D_PMI2'] = rdMolDescriptors.PMI2(mol_3d)
            features['3D_PMI3'] = rdMolDescriptors.PMI3(mol_3d)
            features['3D_NPR1'] = rdMolDescriptors.NPR1(mol_3d)
            features['3D_NPR2'] = rdMolDescriptors.NPR2(mol_3d)
            features['3D_RadiusOfGyration'] = rdMolDescriptors.RadiusOfGyration(mol_3d)
            features['3D_InertialShapeFactor'] = rdMolDescriptors.InertialShapeFactor(mol_3d)
            features['3D_Eccentricity'] = rdMolDescriptors.Eccentricity(mol_3d)
            features['3D_Asphericity'] = rdMolDescriptors.Asphericity(mol_3d)
            features['3D_SpherocityIndex'] = rdMolDescriptors.SpherocityIndex(mol_3d)
        except:
            features = {f'3D_{key}': 0 for key in [
                'PMI1', 'PMI2', 'PMI3', 'NPR1', 'NPR2', 'RadiusOfGyration',
                'InertialShapeFactor', 'Eccentricity', 'Asphericity', 'SpherocityIndex'
            ]}
        
        return features
    
    def get_enhanced_fingerprints(self, mol):
        """Generate enhanced fingerprints"""
        features = {}
        
        # Multiple Morgan fingerprint radii
        for radius in [2, 3, 4]:
            fp = GetMorganFingerprintAsBitVect(mol, radius=radius, nBits=512)
            for i in range(fp.GetNumBits()):
                features[f"Morgan_R{radius}_{i}"] = int(fp.GetBit(i))
        
        # MACCS Keys
        fp_maccs = GetMACCSKeysFingerprint(mol)
        for i in range(fp_maccs.GetNumBits()):
            features[f"MACCS_{i}"] = int(fp_maccs.GetBit(i))
        
        return features
    
    def get_functional_groups(self, mol):
        """Calculate functional group counts"""
        features = {}
        
        # Important patterns for melting point
        patterns = {
            'Hydroxyl': '[OH]',
            'Carbonyl': '[CX3]=[OX1]',
            'Carboxyl': '[CX3](=O)[OX2H1]',
            'Amine': '[NX3;!$(NC=O)]',
            'Ether': '[OD2]([#6])[#6]',
            'Ester': '[#6][CX3](=O)[OX2H0][#6]',
            'Amide': '[NX3][CX3](=[OX1])[#6]',
            'Benzene': 'c1ccccc1',
            'Halogen_F': '[F]',
            'Halogen_Cl': '[Cl]',
            'Halogen_Br': '[Br]'
        }
        
        for name, smarts in patterns.items():
            pattern = Chem.MolFromSmarts(smarts)
            if pattern:
                matches = mol.GetSubstructMatches(pattern)
                features[f'FG_{name}'] = len(matches)
            else:
                features[f'FG_{name}'] = 0
        
        return features
    
    def get_advanced_descriptors(self, mol):
        """Calculate advanced molecular descriptors"""
        features = {}
        
        try:
            features['CrippenLogP'] = Crippen.MolLogP(mol)
            features['CrippenMR'] = Crippen.MolMR(mol)
            features['NumAromaticRings'] = rdMolDescriptors.CalcNumAromaticRings(mol)
            features['NumAliphaticRings'] = rdMolDescriptors.CalcNumAliphaticRings(mol)
            features['FractionCsp3'] = rdMolDescriptors.CalcFractionCsp3(mol)
            features['BertzCT'] = rdMolDescriptors.BertzCT(mol)
            features['BalabanJ'] = rdMolDescriptors.BalabanJ(mol)
            features['Kappa1'] = rdMolDescriptors.Kappa1(mol)
            features['Kappa2'] = rdMolDescriptors.Kappa2(mol)
            features['Chi0'] = rdMolDescriptors.Chi0(mol)
            features['Chi1'] = rdMolDescriptors.Chi1(mol)
        except:
            features = {key: 0 for key in ['CrippenLogP', 'CrippenMR', 'NumAromaticRings', 
                       'NumAliphaticRings', 'FractionCsp3', 'BertzCT', 'BalabanJ',
                       'Kappa1', 'Kappa2', 'Chi0', 'Chi1']}
        
        return features

def generate_enhanced_features_from_smiles(smiles_list):
    """Generate enhanced features from SMILES list"""
    feature_gen = EnhancedMolecularFeatures()
    features = []
    
    for smiles in tqdm(smiles_list, desc="Processing SMILES"):
        mol = Chem.MolFromSmiles(smiles)
        feature_dict = {}
        
        if mol is not None:
            # Original RDKit descriptors - direct calculation (NO IMPORT ISSUES)
            try:
                for desc_name, desc_func in Descriptors.descList:
                    try:
                        feature_dict[desc_name] = desc_func(mol)
                    except:
                        feature_dict[desc_name] = 0
            except:
                pass
            
            # 3D descriptors
            mol_3d = feature_gen.generate_3d_conformer(mol)
            feature_dict.update(feature_gen.get_3d_descriptors(mol_3d))
            
            # Enhanced fingerprints
            feature_dict.update(feature_gen.get_enhanced_fingerprints(mol))
            
            # Functional groups
            feature_dict.update(feature_gen.get_functional_groups(mol))
            
            # Advanced descriptors
            feature_dict.update(feature_gen.get_advanced_descriptors(mol))
        
        features.append(feature_dict)
    
    return features

def parallel_enhanced_feature_generation(smiles_list, num_workers):
    """Generate enhanced features in parallel"""
    chunks = np.array_split(smiles_list, num_workers)
    with multiprocessing.Pool(processes=num_workers) as pool:
        results = pool.map(generate_enhanced_features_from_smiles, chunks)
    
    return [item for sublist in results for item in sublist]

# Get number of cores
num_cores = multiprocessing.cpu_count()
print(f"Using {num_cores} CPU cores for enhanced feature generation.")

# Generate enhanced features for both training and test sets
print("🚀 Generating enhanced molecular features...")
train_features_list = parallel_enhanced_feature_generation(train_df[SMILES_COL].tolist(), num_cores)
test_features_list = parallel_enhanced_feature_generation(test_df[SMILES_COL].tolist(), num_cores)

# Convert to DataFrames
train_enhanced_features = pd.DataFrame(train_features_list).fillna(0)
test_enhanced_features = pd.DataFrame(test_features_list).fillna(0)

print(f"✅ Generated {train_enhanced_features.shape[1]} enhanced features!")

# Ensure same columns in both datasets
common_features = list(set(train_enhanced_features.columns) & set(test_enhanced_features.columns))
train_enhanced_features = train_enhanced_features[common_features]
test_enhanced_features = test_enhanced_features[common_features]

# Remove constant features
constant_features = []
for col in train_enhanced_features.columns:
    if train_enhanced_features[col].nunique() <= 1:
        constant_features.append(col)

train_enhanced_features = train_enhanced_features.drop(columns=constant_features)
test_enhanced_features = test_enhanced_features.drop(columns=constant_features)

print(f"🗑️  Removed {len(constant_features)} constant features")

# Combine with existing features and target
train_ag = pd.concat([train_df.drop(columns=[SMILES_COL, ID_COL]), train_enhanced_features], axis=1)
test_ag = pd.concat([test_df.drop(columns=[SMILES_COL, ID_COL]), test_enhanced_features], axis=1)

print(f"✅ Final dataset shapes:")
print(f"Train: {train_ag.shape}")
print(f"Test: {test_ag.shape}")
print(f"🎯 Enhanced feature engineering completed with {train_ag.shape[1]} total features!")
# Out:
# Train data shape: (2662, 427)
# Test data shape: (666, 426)
# Using 4 CPU cores for enhanced feature generation.
# 🚀 Generating enhanced molecular features...
# Processing SMILES:   0%|          | 0/666 [00:00<?, ?it/s][10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   0%|          | 1/665 [00:00<01:21,  8.10it/s][10:42:27] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   0%|          | 1/666 [00:00<01:21,  8.14it/s][10:42:27] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   0%|          | 1/665 [00:00<01:26,  7.72it/s][10:42:27] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   0%|          | 1/666 [00:00<01:35,  6.97it/s][10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   1%|          | 4/665 [00:00<00:34, 18.89it/s][10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   0%|          | 3/666 [00:00<00:50, 13.18it/s][10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   1%|          | 4/665 [00:00<00:40, 16.31it/s][10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   1%|          | 6/666 [00:00<00:35, 18.48it/s][10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   1%|          | 7/665 [00:00<00:32, 20.17it/s][10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   1%|          | 6/665 [00:00<00:49, 13.36it/s][10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   2%|▏         | 10/665 [00:00<00:28, 22.81it/s][10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   2%|▏         | 11/666 [00:00<00:31, 20.61it/s][10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   2%|▏         | 10/665 [00:00<00:36, 17.73it/s][10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   2%|▏         | 13/665 [00:00<00:33, 19.50it/s][10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# [10:42:27] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   2%|▏         | 13/665 [00:00<00:33, 19.43it/s][10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   2%|▏         | 16/665 [00:00<00:34, 18.88it/s][10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   2%|▏         | 16/665 [00:00<00:30, 21.20it/s][10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   2%|▏         | 14/666 [00:00<00:43, 15.13it/s][10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   1%|          | 8/666 [00:00<01:30,  7.29it/s][10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   3%|▎         | 19/665 [00:00<00:31, 20.20it/s][10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   2%|▏         | 11/666 [00:01<01:01, 10.62it/s][10:42:28] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   2%|▏         | 16/666 [00:01<00:45, 14.21it/s][10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   3%|▎         | 22/665 [00:01<00:31, 20.64it/s][10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   3%|▎         | 22/665 [00:01<00:30, 21.30it/s][10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   3%|▎         | 19/666 [00:01<00:37, 17.07it/s][10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   2%|▏         | 14/666 [00:01<00:48, 13.51it/s][10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   4%|▍         | 25/665 [00:01<00:28, 22.21it/s][10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   3%|▎         | 17/666 [00:01<00:40, 16.11it/s][10:42:28] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   3%|▎         | 22/666 [00:01<00:34, 18.68it/s][10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   4%|▍         | 25/665 [00:01<00:32, 19.63it/s][10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   4%|▍         | 28/665 [00:01<00:32, 19.66it/s][10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   4%|▍         | 28/665 [00:01<00:30, 20.85it/s][10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   4%|▍         | 25/666 [00:01<00:33, 18.94it/s][10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   3%|▎         | 20/666 [00:01<00:41, 15.66it/s][10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   4%|▍         | 28/666 [00:01<00:30, 21.11it/s][10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   3%|▎         | 22/666 [00:01<00:40, 15.97it/s][10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   5%|▍         | 31/665 [00:01<00:40, 15.65it/s][10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   5%|▍         | 32/666 [00:01<00:28, 22.36it/s][10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   4%|▍         | 25/666 [00:01<00:34, 18.47it/s][10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:28] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   5%|▍         | 31/665 [00:01<00:43, 14.44it/s][10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   5%|▌         | 34/665 [00:01<00:35, 17.59it/s][10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   5%|▌         | 34/665 [00:01<00:38, 16.56it/s][10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   6%|▌         | 38/665 [00:01<00:28, 21.92it/s][10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   4%|▍         | 28/666 [00:01<00:41, 15.29it/s][10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   5%|▌         | 35/666 [00:02<00:38, 16.41it/s][10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   6%|▌         | 41/665 [00:02<00:27, 22.40it/s][10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   5%|▍         | 30/666 [00:02<00:39, 16.14it/s][10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   6%|▌         | 37/666 [00:02<00:38, 16.14it/s][10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   6%|▌         | 40/665 [00:02<00:32, 19.28it/s][10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   5%|▍         | 32/666 [00:02<00:42, 14.78it/s][10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   7%|▋         | 47/665 [00:02<00:25, 24.47it/s][10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   6%|▌         | 40/666 [00:02<00:35, 17.41it/s][10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   6%|▋         | 43/665 [00:02<00:31, 19.87it/s][10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   5%|▌         | 34/666 [00:02<00:40, 15.61it/s][10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   8%|▊         | 50/665 [00:02<00:25, 24.28it/s][10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   6%|▋         | 43/666 [00:02<00:34, 18.24it/s][10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   7%|▋         | 46/665 [00:02<00:30, 20.23it/s][10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   6%|▌         | 37/666 [00:02<00:34, 18.31it/s][10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   8%|▊         | 53/665 [00:02<00:29, 20.52it/s][10:42:29] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   7%|▋         | 49/665 [00:02<00:30, 20.07it/s][10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   6%|▌         | 39/666 [00:02<00:39, 15.70it/s][10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   7%|▋         | 45/666 [00:02<00:42, 14.53it/s][10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   8%|▊         | 56/665 [00:02<00:28, 21.64it/s][10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:29] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   6%|▌         | 41/666 [00:02<00:38, 16.04it/s][10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   9%|▉         | 59/665 [00:02<00:27, 21.74it/s][10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   6%|▋         | 43/666 [00:02<00:37, 16.82it/s][10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   8%|▊         | 52/665 [00:02<00:39, 15.70it/s][10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   8%|▊         | 51/666 [00:02<00:33, 18.54it/s][10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] UFFTYPER: Unrecognized charge state for atom: 1
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   7%|▋         | 45/666 [00:02<00:35, 17.36it/s][10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   8%|▊         | 54/665 [00:03<00:38, 15.79it/s][10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   8%|▊         | 54/666 [00:03<00:32, 18.84it/s][10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   8%|▊         | 56/665 [00:03<00:41, 14.52it/s][10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   9%|▊         | 57/666 [00:03<00:35, 17.35it/s][10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   9%|▉         | 60/666 [00:03<00:31, 19.12it/s][10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   9%|▊         | 58/665 [00:03<00:49, 12.15it/s][10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   9%|▉         | 62/665 [00:03<00:56, 10.73it/s][10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   9%|▉         | 63/666 [00:03<00:28, 21.07it/s][10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   9%|▉         | 61/665 [00:03<00:41, 14.68it/s][10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  10%|▉         | 64/665 [00:03<00:51, 11.61it/s][10:42:30] DEPRECATION WARNING: please use MorganGenerator
# [10:42:30] DEPRECATION WARNING: please use MorganGenerator
# ...
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  92%|█████████▏| 152/166 [00:08<00:00, 21.56it/s][10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  96%|█████████▌| 160/167 [00:08<00:00, 15.96it/s][10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  90%|█████████ | 150/166 [00:08<00:00, 16.74it/s][10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  93%|█████████▎| 155/166 [00:08<00:00, 21.37it/s][10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  98%|█████████▊| 163/167 [00:08<00:00, 18.59it/s][10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  78%|███████▊  | 131/167 [00:08<00:02, 15.90it/s][10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  92%|█████████▏| 153/166 [00:08<00:00, 18.38it/s][10:43:18] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  95%|█████████▌| 158/166 [00:08<00:00, 22.55it/s][10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  99%|█████████▉| 166/167 [00:08<00:00, 19.50it/s][10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  80%|███████▉  | 133/167 [00:08<00:02, 16.44it/s][10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES: 100%|██████████| 167/167 [00:08<00:00, 18.58it/s]
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  97%|█████████▋| 161/166 [00:09<00:00, 23.64it/s][10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  81%|████████  | 135/167 [00:09<00:01, 16.71it/s][10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  94%|█████████▍| 156/166 [00:09<00:00, 16.50it/s][10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  99%|█████████▉| 164/166 [00:09<00:00, 22.85it/s][10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  82%|████████▏ | 137/167 [00:09<00:01, 15.22it/s][10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  95%|█████████▌| 158/166 [00:09<00:00, 15.58it/s][10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES: 100%|██████████| 166/166 [00:09<00:00, 17.67it/s]
# Processing SMILES:  84%|████████▍ | 141/167 [00:09<00:01, 18.61it/s][10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# [10:43:18] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  98%|█████████▊| 162/166 [00:09<00:00, 18.46it/s][10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  87%|████████▋ | 145/167 [00:09<00:01, 21.69it/s][10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES: 100%|██████████| 166/166 [00:09<00:00, 17.34it/s]
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  89%|████████▊ | 148/167 [00:09<00:00, 21.23it/s][10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  90%|█████████ | 151/167 [00:09<00:00, 23.01it/s][10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  93%|█████████▎| 156/167 [00:09<00:00, 28.63it/s][10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  96%|█████████▋| 161/167 [00:10<00:00, 32.46it/s][10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# [10:43:19] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES: 100%|██████████| 167/167 [00:10<00:00, 16.46it/s]
# ✅ Generated 1944 enhanced features!
# 🗑️  Removed 51 constant features
# ✅ Final dataset shapes:
# Train: (2662, 2318)
# Test: (666, 2317)
# 🎯 Enhanced feature engineering completed with 2318 total features!

# %% [markdown]
# <!-- ================= H2 HEADER: Execute Feature Generation ================= -->
# <div style="border-radius:25px 70px; padding:14px 18px; margin:10px 0;
#             font-family:'Quicksand', sans-serif; background:#24a695; overflow:hidden;">
#   <div style="text-align:center; color:#ffffff; font-size:150%; margin:0; padding:0;">
#     <b><h2 style="margin:0; color:#ffffff;">Execute Feature Generation</h2></b>
#   </div>
# </div>

# %%
print(f"Shape of training data after RDKit feature generation: {train_ag.shape}")
print(f"Shape of test data after RDKit feature generation: {test_ag.shape}")
print(f"Number of total features: {test_ag.shape[1]}")
# Out:
# Shape of training data after RDKit feature generation: (2662, 2318)
# Shape of test data after RDKit feature generation: (666, 2317)
# Number of total features: 2317

# %% [markdown]
# <!-- ================= H2 HEADER: AutoGluon Training and Prediction ================= -->
# <div style="border-radius:25px 70px; padding:14px 18px; margin:10px 0;
#             font-family:'Quicksand', sans-serif; background:#24a695; overflow:hidden;">
#   <div style="text-align:center; color:#ffffff; font-size:150%; margin:0; padding:0;">
#     <b><h2 style="margin:0; color:#ffffff;">AutoGluon Training and Prediction</h2></b>
#   </div>
# </div>
#
# <!-- ================= BADGES: AutoGluon Training Steps ================= -->
# <div style="display:flex; gap:10px; flex-wrap:wrap; justify-content:center; margin:12px 0; font-family:Inter, system-ui, 'Segoe UI', Roboto, Arial, sans-serif;">
#   <span style="background:#e2e8f0; color:#0f172a; padding:6px 14px; border-radius:999px; font-size:13px; border:1px solid #cbd5e1;">Initialize Predictor</span>
#   <span style="background:#dbeafe; color:#1e3a8a; padding:6px 14px; border-radius:999px; font-size:13px; border:1px solid #bfdbfe;">Set Label & Problem Type</span>
#   <span style="background:#dcfce7; color:#14532d; padding:6px 14px; border-radius:999px; font-size:13px; border:1px solid #bbf7d0;">Fit Model on Train Data</span>
#   <span style="background:#fde68a; color:#92400e; padding:6px 14px; border-radius:999px; font-size:13px; border:1px solid #fcd34d;">Set Time Limit & Presets</span>
# </div>

# %%
predictor = TabularPredictor(
    label=TARGET,
    problem_type='regression',
    eval_metric='mae'
).fit(
    train_data=train_ag,
    time_limit=3600*11,
    presets='best_quality' 
)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20250914_104327"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.4.0
# Python Version:     3.11.13
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP PREEMPT_DYNAMIC Sun Nov 10 10:07:59 UTC 2024
# CPU Count:          4
# Memory Avail:       29.43 GB / 31.35 GB (93.9%)
# Disk Space Avail:   19.50 GB / 19.52 GB (99.9%)
# ===================================================
# Presets specified: ['best_quality']
# Using hyperparameters preset: hyperparameters='zeroshot'
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 9900s of the 39600s of remaining time (25%).
# 		Context path: "/kaggle/working/AutogluonModels/ag-20250914_104327/ds_sub_fit/sub_fit_ho"
# Running DyStack sub-fit ...
# Beginning AutoGluon training ... Time limit = 9899s
# AutoGluon will save models to "/kaggle/working/AutogluonModels/ag-20250914_104327/ds_sub_fit/sub_fit_ho"
# Train Data Rows:    2366
# Train Data Columns: 2317
# Label Column:       Tm
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    30073.78 MB
# 	Train Data (Original)  Memory Usage: 41.82 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 1882 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Useless Original Features (Count: 93): ['Group 12', 'Group 28', 'Group 46', 'Group 67', 'Group 73', 'Group 74', 'Group 75', 'Group 84', 'Group 85', 'Group 88', 'Group 90', 'Group 93', 'Group 101', 'Group 102', 'Group 104', 'Group 107', 'Group 137', 'Group 150', 'Group 152', 'Group 155', 'Group 158', 'Group 160', 'Group 167', 'Group 183', 'Group 194', 'Group 198', 'Group 206', 'Group 207', 'Group 208', 'Group 209', 'Group 212', 'Group 213', 'Group 214', 'Group 215', 'Group 216', 'Group 217', 'Group 218', 'Group 245', 'Group 247', 'Group 248', 'Group 250', 'Group 252', 'Group 253', 'Group 256', 'Group 264', 'Group 280', 'Group 281', 'Group 282', 'Group 285', 'Group 294', 'Group 299', 'Group 303', 'Group 306', 'Group 307', 'Group 308', 'Group 309', 'Group 312', 'Group 313', 'Group 316', 'Group 317', 'Group 340', 'Group 342', 'Group 345', 'Group 347', 'Group 348', 'Group 349', 'Group 350', 'Group 352', 'Group 355', 'Group 356', 'Group 357', 'Group 358', 'Group 360', 'Group 363', 'Group 371', 'Group 376', 'Group 377', 'Group 383', 'Group 384', 'Group 385', 'Group 390', 'Group 397', 'Group 399', 'Group 410', 'Group 411', 'Group 413', 'Group 417', 'Group 419', 'Group 420', 'Group 421', 'Group 422', 'Group 423', 'Group 424']
# 		These features carry no predictive signal and should be manually investigated.
# 		This is typically a feature which has the same value for all rows.
# 		These features do not need to be present at inference time.
# 	Unused Original Features (Count: 44): ['Group 386', 'Morgan_R4_76', 'Morgan_R3_490', 'fr_phos_ester', 'fr_Nhpyrrole', 'MACCS_60', 'FG_Ether', 'MACCS_127', 'Morgan_R3_49', 'fr_COO2', 'fr_COO', 'NumAmideBonds', 'fr_isocyan', 'fr_ester', 'FG_Benzene', 'FG_Carbonyl', 'Morgan_R4_62', 'Morgan_R4_124', 'Morgan_R4_310', 'Morgan_R3_360', 'Morgan_R4_331', 'Morgan_R3_271', 'Morgan_R3_108', 'Morgan_R3_221', 'MACCS_40', 'Morgan_R4_233', 'fr_azo', 'Morgan_R3_343', 'Morgan_R3_282', 'MaxAbsEStateIndex', 'NumAtomStereoCenters', 'Morgan_R3_142', 'Morgan_R3_131', 'Morgan_R4_287', 'Morgan_R4_289', 'Morgan_R3_79', 'Morgan_R3_337', 'Morgan_R3_259', 'Morgan_R4_175', 'MACCS_13', 'NumAromaticCarbocycles', 'fr_nitroso', 'fr_phenol', 'Morgan_R4_169']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('float', []) :  1 | ['MaxAbsEStateIndex']
# 		('int', [])   : 43 | ['Group 386', 'Morgan_R4_76', 'Morgan_R3_490', 'fr_phos_ester', 'fr_Nhpyrrole', ...]
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) :   97 | ['SMR_VSA7', 'PEOE_VSA1', 'MolMR', 'AvgIpc', 'EState_VSA5', ...]
# 		('int', [])   : 2083 | ['Group 1', 'Group 2', 'Group 3', 'Group 4', 'Group 5', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     :   97 | ['SMR_VSA7', 'PEOE_VSA1', 'MolMR', 'AvgIpc', 'EState_VSA5', ...]
# 		('int', [])       :  233 | ['Group 1', 'Group 2', 'Group 3', 'Group 4', 'Group 5', ...]
# 		('int', ['bool']) : 1850 | ['Group 10', 'Group 11', 'Group 14', 'Group 24', 'Group 26', ...]
# 	30.5s = Fit runtime
# 	2180 features in original data used to generate 2180 features in processed data.
# 	Train Data (Processed) Memory Usage: 10.13 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 30.79s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (110 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 106 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 6577.01s of the 9867.97s of remaining time.
# Will use sequential fold fitting strategy because import of ray failed. Reason: ray==2.47.1 detected. 2.10.0 <= ray < 2.45.0 is required. You can use pip to install certain version of ray `pip install "ray>=2.10.0,<2.45.0"`
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# [1000]	valid_set's l1: 27.692
# [2000]	valid_set's l1: 27.4664
# [3000]	valid_set's l1: 27.3893
# [4000]	valid_set's l1: 27.3511
# [5000]	valid_set's l1: 27.3321
# [6000]	valid_set's l1: 27.3532
# 	-27.4092	 = Validation score   (-mean_absolute_error)
# 	80.54s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 6489.55s of the 9780.51s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-28.3098	 = Validation score   (-mean_absolute_error)
# 	51.31s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 6436.91s of the 9727.87s of remaining time.
# 	-29.6462	 = Validation score   (-mean_absolute_error)
# 	93.23s	 = Training   runtime
# 	2.1s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 6340.85s of the 9631.81s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-27.0098	 = Validation score   (-mean_absolute_error)
# 	1733.55s	 = Training   runtime
# 	0.94s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 4605.18s of the 7896.14s of remaining time.
# 	-29.6332	 = Validation score   (-mean_absolute_error)
# 	75.66s	 = Training   runtime
# 	2.12s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 4526.73s of the 7817.69s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-30.7385	 = Validation score   (-mean_absolute_error)
# 	75.51s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 4449.56s of the 7740.52s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-28.4204	 = Validation score   (-mean_absolute_error)
# 	259.62s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 4188.48s of the 7479.44s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-29.3509	 = Validation score   (-mean_absolute_error)
# 	207.39s	 = Training   runtime
# 	1.41s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 3978.56s of the 7269.52s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# [1000]	valid_set's l1: 24.1351
# [2000]	valid_set's l1: 24.1349
# [3000]	valid_set's l1: 24.1349
# [4000]	valid_set's l1: 24.1349
# [5000]	valid_set's l1: 24.1349
# [6000]	valid_set's l1: 24.1349
# [7000]	valid_set's l1: 24.1349
# [8000]	valid_set's l1: 24.1349
# [1000]	valid_set's l1: 30.2911
# [2000]	valid_set's l1: 30.2902
# [3000]	valid_set's l1: 30.2902
# [4000]	valid_set's l1: 30.2902
# [5000]	valid_set's l1: 30.2902
# [6000]	valid_set's l1: 30.2902
# [7000]	valid_set's l1: 30.2902
# [8000]	valid_set's l1: 30.2902
# [9000]	valid_set's l1: 30.2902
# [10000]	valid_set's l1: 30.2902
# [1000]	valid_set's l1: 26.1825
# [2000]	valid_set's l1: 26.1822
# [1000]	valid_set's l1: 31.5918
# [2000]	valid_set's l1: 31.5916
# [3000]	valid_set's l1: 31.5916
# [4000]	valid_set's l1: 31.5916
# [5000]	valid_set's l1: 31.5916
# [6000]	valid_set's l1: 31.5916
# [1000]	valid_set's l1: 29.2974
# 	-29.0337	 = Validation score   (-mean_absolute_error)
# 	1038.35s	 = Training   runtime
# 	2.41s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 2926.50s of the 6217.46s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	Ran out of time, early stopping on iteration 9124.
# 	-27.5307	 = Validation score   (-mean_absolute_error)
# 	1159.99s	 = Training   runtime
# 	0.68s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 1764.71s of the 5055.67s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-33.0449	 = Validation score   (-mean_absolute_error)
# 	210.82s	 = Training   runtime
# 	1.4s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 1551.38s of the 4842.34s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# [1000]	valid_set's l1: 28.7348
# [1000]	valid_set's l1: 24.149
# [1000]	valid_set's l1: 26.6787
# [1000]	valid_set's l1: 26.7054
# [2000]	valid_set's l1: 26.6133
# [3000]	valid_set's l1: 26.5709
# [4000]	valid_set's l1: 26.5588
# [5000]	valid_set's l1: 26.5736
# [1000]	valid_set's l1: 29.6471
# [1000]	valid_set's l1: 27.6159
# [2000]	valid_set's l1: 27.4571
# 	-27.9267	 = Validation score   (-mean_absolute_error)
# 	186.2s	 = Training   runtime
# 	0.56s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 1362.17s of the 4653.13s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-30.1173	 = Validation score   (-mean_absolute_error)
# 	187.41s	 = Training   runtime
# 	0.36s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 1172.98s of the 4463.94s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	Ran out of time, early stopping on iteration 954.
# 	Ran out of time, early stopping on iteration 963.
# 	Ran out of time, early stopping on iteration 954.
# 	Ran out of time, early stopping on iteration 1034.
# 	Ran out of time, early stopping on iteration 1123.
# 	Ran out of time, early stopping on iteration 1190.
# 	Ran out of time, early stopping on iteration 1423.
# 	Ran out of time, early stopping on iteration 1784.
# 	-27.8592	 = Validation score   (-mean_absolute_error)
# 	1123.21s	 = Training   runtime
# 	1.14s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 47.49s of the 3338.45s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# [1000]	valid_set's l1: 29.4534
# 	Ran out of time, early stopping on iteration 1143. Best iteration is:
# 	[1143]	valid_set's l1: 29.1833
# [1000]	valid_set's l1: 25.0183
# 	Ran out of time, early stopping on iteration 1177. Best iteration is:
# 	[1171]	valid_set's l1: 24.7336
# [1000]	valid_set's l1: 28.1111
# 	Ran out of time, early stopping on iteration 1198. Best iteration is:
# 	[1198]	valid_set's l1: 27.7678
# [1000]	valid_set's l1: 29.857
# 	Ran out of time, early stopping on iteration 1256. Best iteration is:
# 	[1256]	valid_set's l1: 29.6817
# [1000]	valid_set's l1: 28.5302
# 	Ran out of time, early stopping on iteration 1341. Best iteration is:
# 	[1341]	valid_set's l1: 27.9939
# [1000]	valid_set's l1: 30.7561
# 	Ran out of time, early stopping on iteration 1133. Best iteration is:
# 	[1113]	valid_set's l1: 30.6019
# [1000]	valid_set's l1: 28.3233
# 	Ran out of time, early stopping on iteration 1595. Best iteration is:
# 	[1595]	valid_set's l1: 27.5193
# [1000]	valid_set's l1: 32.0747
# 	Ran out of time, early stopping on iteration 1901. Best iteration is:
# 	[1900]	valid_set's l1: 31.4675
# 	-28.6179	 = Validation score   (-mean_absolute_error)
# 	44.19s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 1.51s of the 3292.48s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	Warning: Model has no time left to train, skipping model... (Time Left = -0.5s)
# 	Time limit exceeded... Skipping NeuralNetTorch_r22_BAG_L1.
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 657.70s of the 3290.48s of remaining time.
# 	Ensemble Weights: {'CatBoost_BAG_L1': 0.304, 'LightGBMXT_BAG_L1': 0.217, 'NeuralNetTorch_r79_BAG_L1': 0.13, 'NeuralNetTorch_BAG_L1': 0.087, 'LightGBM_r131_BAG_L1': 0.087, 'NeuralNetFastAI_r191_BAG_L1': 0.087, 'XGBoost_BAG_L1': 0.043, 'CatBoost_r177_BAG_L1': 0.043}
# 	-26.0053	 = Validation score   (-mean_absolute_error)
# 	0.1s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 106 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 3290.36s of the 3290.32s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-27.7252	 = Validation score   (-mean_absolute_error)
# 	27.8s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 3261.42s of the 3261.38s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-27.7952	 = Validation score   (-mean_absolute_error)
# 	36.53s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ... Training model for up to 3223.72s of the 3223.68s of remaining time.
# 	-27.0258	 = Validation score   (-mean_absolute_error)
# 	103.21s	 = Training   runtime
# 	2.1s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 3117.64s of the 3117.60s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-26.651	 = Validation score   (-mean_absolute_error)
# 	124.96s	 = Training   runtime
# 	0.99s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ... Training model for up to 2990.60s of the 2990.56s of remaining time.
# 	-26.8841	 = Validation score   (-mean_absolute_error)
# 	82.48s	 = Training   runtime
# 	2.11s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 2905.24s of the 2905.19s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-31.0213	 = Validation score   (-mean_absolute_error)
# 	76.79s	 = Training   runtime
# 	0.29s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 2826.79s of the 2826.75s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-27.6079	 = Validation score   (-mean_absolute_error)
# 	74.85s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 2750.70s of the 2750.66s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-28.837	 = Validation score   (-mean_absolute_error)
# 	109.43s	 = Training   runtime
# 	1.45s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 2638.67s of the 2638.62s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-28.6911	 = Validation score   (-mean_absolute_error)
# 	136.82s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L2 ... Training model for up to 2500.45s of the 2500.40s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-26.7757	 = Validation score   (-mean_absolute_error)
# 	106.03s	 = Training   runtime
# 	0.65s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L2 ... Training model for up to 2392.72s of the 2392.68s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-33.9446	 = Validation score   (-mean_absolute_error)
# 	159.37s	 = Training   runtime
# 	1.42s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L2 ... Training model for up to 2230.78s of the 2230.73s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-27.6608	 = Validation score   (-mean_absolute_error)
# 	64.44s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L2 ... Training model for up to 2164.92s of the 2164.87s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# No improvement since epoch 11: early stopping
# 	-30.8544	 = Validation score   (-mean_absolute_error)
# 	179.32s	 = Training   runtime
# 	0.42s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L2 ... Training model for up to 1983.71s of the 1983.67s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-26.6379	 = Validation score   (-mean_absolute_error)
# 	529.31s	 = Training   runtime
# 	0.73s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L2 ... Training model for up to 1452.59s of the 1452.54s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-27.397	 = Validation score   (-mean_absolute_error)
# 	25.93s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L2 ... Training model for up to 1425.44s of the 1425.39s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-27.6519	 = Validation score   (-mean_absolute_error)
# 	114.71s	 = Training   runtime
# 	1.46s	 = Validation runtime
# Fitting model: XGBoost_r33_BAG_L2 ... Training model for up to 1308.12s of the 1308.08s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-27.7831	 = Validation score   (-mean_absolute_error)
# 	242.96s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: ExtraTrees_r42_BAG_L2 ... Training model for up to 1063.71s of the 1063.66s of remaining time.
# 	-26.9315	 = Validation score   (-mean_absolute_error)
# 	63.53s	 = Training   runtime
# 	2.15s	 = Validation runtime
# Fitting model: CatBoost_r137_BAG_L2 ... Training model for up to 997.35s of the 997.31s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-26.4641	 = Validation score   (-mean_absolute_error)
# 	64.41s	 = Training   runtime
# 	1.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r102_BAG_L2 ... Training model for up to 930.90s of the 930.85s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# No improvement since epoch 0: early stopping
# 	-37.0693	 = Validation score   (-mean_absolute_error)
# 	48.39s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: CatBoost_r13_BAG_L2 ... Training model for up to 880.82s of the 880.77s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	Ran out of time, early stopping on iteration 1113.
# 	-26.5818	 = Validation score   (-mean_absolute_error)
# 	530.81s	 = Training   runtime
# 	1.05s	 = Validation runtime
# Fitting model: RandomForest_r195_BAG_L2 ... Training model for up to 347.87s of the 347.83s of remaining time.
# 	-27.0586	 = Validation score   (-mean_absolute_error)
# 	78.43s	 = Training   runtime
# 	2.12s	 = Validation runtime
# Fitting model: LightGBM_r188_BAG_L2 ... Training model for up to 266.59s of the 266.54s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-28.0892	 = Validation score   (-mean_absolute_error)
# 	80.01s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145_BAG_L2 ... Training model for up to 185.05s of the 185.01s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-32.2277	 = Validation score   (-mean_absolute_error)
# 	135.08s	 = Training   runtime
# 	0.36s	 = Validation runtime
# Fitting model: XGBoost_r89_BAG_L2 ... Training model for up to 48.22s of the 48.18s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-27.2963	 = Validation score   (-mean_absolute_error)
# 	44.19s	 = Training   runtime
# 	0.19s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.00s of the 2.53s of remaining time.
# 	Ensemble Weights: {'CatBoost_r137_BAG_L2': 0.409, 'LightGBMXT_BAG_L1': 0.182, 'ExtraTreesMSE_BAG_L2': 0.136, 'NeuralNetTorch_r22_BAG_L2': 0.136, 'NeuralNetFastAI_r191_BAG_L1': 0.091, 'RandomForestMSE_BAG_L2': 0.045}
# 	-26.1937	 = Validation score   (-mean_absolute_error)
# 	0.13s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 9896.43s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 49.8 rows/s (296 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/kaggle/working/AutogluonModels/ag-20250914_104327/ds_sub_fit/sub_fit_ho")
# Deleting DyStack predictor artifacts (clean_up_fits=True) ...
# Leaderboard on holdout data (DyStack):
#                           model  score_holdout  score_val          eval_metric  pred_time_test  pred_time_val     fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0           WeightedEnsemble_L3     -26.168105 -26.193725  mean_absolute_error       13.031790      17.114510  4634.861674                 0.003770                0.000761           0.131668            3       True         42
# 1               CatBoost_BAG_L2     -26.169165 -26.650956  mean_absolute_error       10.951710      11.436793  4394.877940                 1.013535                0.991465         124.963247            2       True         20
# 2           CatBoost_r13_BAG_L2     -26.227567 -26.581812  mean_absolute_error       10.996321      11.496410  4800.723496                 1.058147                1.051082         530.808804            2       True         37
# 3        RandomForestMSE_BAG_L2     -26.240944 -27.025792  mean_absolute_error       10.086479      12.543668  4373.121721                 0.148304                2.098340         103.207028            2       True         19
# 4          CatBoost_r137_BAG_L2     -26.276846 -26.464099  mean_absolute_error       11.273391      11.444834  4334.328861                 1.335216                0.999506          64.414169            2       True         35
# 5      RandomForest_r195_BAG_L2     -26.296476 -27.058571  mean_absolute_error       10.082729      12.563203  4348.347553                 0.144555                2.117875          78.432861            2       True         38
# 6            CatBoost_r9_BAG_L2     -26.354059 -26.637884  mean_absolute_error       11.034367      11.178134  4799.220629                 1.096193                0.732806         529.305937            2       True         30
# 7          CatBoost_r177_BAG_L2     -26.370877 -26.775682  mean_absolute_error       10.954208      11.099646  4375.948787                 1.016033                0.654318         106.034094            2       True         26
# 8         ExtraTrees_r42_BAG_L2     -26.409640 -26.931537  mean_absolute_error       10.083236      12.594797  4333.449476                 0.145062                2.149468          63.534784            2       True         34
# 9                XGBoost_BAG_L2     -26.455215 -27.607886  mean_absolute_error       10.209164      10.619135  4344.760879                 0.270989                0.173806          74.846186            2       True         23
# 10           XGBoost_r33_BAG_L2     -26.509314 -27.783148  mean_absolute_error       10.328574      10.674532  4512.873844                 0.390400                0.229204         242.959151            2       True         33
# 11         LightGBM_r188_BAG_L2     -26.547583 -28.089151  mean_absolute_error       10.173417      10.594449  4349.921103                 0.235243                0.149121          80.006411            2       True         39
# 12         ExtraTreesMSE_BAG_L2     -26.591266 -26.884133  mean_absolute_error       10.085968      12.551195  4352.395284                 0.147793                2.105867          82.480592            2       True         21
# 13          WeightedEnsemble_L2     -26.595823 -26.005270  mean_absolute_error        8.757806       5.945544  4025.612535                 0.005513                0.000775           0.101103            2       True         16
# 14            LightGBMXT_BAG_L2     -26.601495 -27.725170  mean_absolute_error       10.060245      10.565403  4297.718116                 0.122071                0.120075          27.803423            2       True         17
# 15         LightGBM_r131_BAG_L2     -26.648151 -27.660794  mean_absolute_error       10.138858      10.592996  4334.356592                 0.200683                0.147668          64.441899            2       True         28
# 16           XGBoost_r89_BAG_L2     -26.762521 -27.296315  mean_absolute_error       10.189234      10.630979  4314.100081                 0.251060                0.185651          44.185389            2       True         41
# 17         LightGBMLarge_BAG_L2     -26.885328 -28.691084  mean_absolute_error       10.117272      10.576458  4406.739639                 0.179097                0.131130         136.824946            2       True         25
# 18              LightGBM_BAG_L2     -26.989501 -27.795166  mean_absolute_error       10.058369      10.564953  4306.448907                 0.120194                0.119625          36.534214            2       True         18
# 19          LightGBM_r96_BAG_L2     -27.151800 -27.396980  mean_absolute_error       10.111421      10.594843  4295.844077                 0.173247                0.149515          25.929384            2       True         31
# 20              CatBoost_BAG_L1     -27.488097 -27.009776  mean_absolute_error        1.491487       0.943542  1733.552587                 1.491487                0.943542        1733.552587            1       True          4
# 21            LightGBMXT_BAG_L1     -27.560089 -27.409235  mean_absolute_error        0.626496       0.307502    80.535401                 0.626496                0.307502          80.535401            1       True          1
# 22    NeuralNetTorch_r22_BAG_L2     -27.601355 -27.651886  mean_absolute_error       11.396706      11.910036  4384.628218                 1.458532                1.464708         114.713525            2       True         32
# 23         CatBoost_r177_BAG_L1     -27.639822 -27.530656  mean_absolute_error        1.178404       0.676470  1159.992721                 1.178404                0.676470        1159.992721            1       True         10
# 24       NeuralNetFastAI_BAG_L2     -27.657296 -31.021260  mean_absolute_error       10.264733      10.734623  4346.707308                 0.326559                0.289295          76.792615            2       True         22
# 25  NeuralNetFastAI_r191_BAG_L1     -27.700069 -30.117258  mean_absolute_error        0.455047       0.363916   187.405942                 0.455047                0.363916         187.405942            1       True         13
# 26  NeuralNetFastAI_r191_BAG_L2     -27.844877 -30.854380  mean_absolute_error       10.361849      10.868240  4449.238657                 0.423675                0.422911         179.323964            2       True         29
# 27               XGBoost_BAG_L1     -28.037095 -28.420352  mean_absolute_error        0.625435       0.283175   259.620305                 0.625435                0.283175         259.620305            1       True          7
# 28       NeuralNetFastAI_BAG_L1     -28.447594 -30.738510  mean_absolute_error        0.342343       0.276649    75.506221                 0.342343                0.276649          75.506221            1       True          6
# 29        NeuralNetTorch_BAG_L2     -28.523751 -28.836974  mean_absolute_error       11.399214      11.893719  4379.347439                 1.461040                1.448391         109.432746            2       True         24
# 30           CatBoost_r9_BAG_L1     -28.550951 -27.859192  mean_absolute_error        1.222170       1.139338  1123.206644                 1.222170                1.139338        1123.206644            1       True         14
# 31         LightGBM_r131_BAG_L1     -28.601924 -27.926713  mean_absolute_error        1.076051       0.562256   186.200259                 1.076051                0.562256         186.200259            1       True         12
# 32          LightGBM_r96_BAG_L1     -28.867986 -28.617884  mean_absolute_error        0.433584       0.300838    44.188606                 0.433584                0.300838          44.188606            1       True         15
# 33              LightGBM_BAG_L1     -29.144466 -28.309755  mean_absolute_error        0.273959       0.166633    51.312349                 0.273959                0.166633          51.312349            1       True          2
# 34    NeuralNetTorch_r79_BAG_L1     -29.441617 -33.044859  mean_absolute_error        1.522484       1.398109   210.815518                 1.522484                1.398109         210.815518            1       True         11
# 35         LightGBMLarge_BAG_L1     -29.567651 -29.033669  mean_absolute_error        5.889297       2.411318  1038.350040                 5.889297                2.411318        1038.350040            1       True          9
# 36  NeuralNetFastAI_r145_BAG_L2     -29.587409 -32.227673  mean_absolute_error       10.334274      10.805100  4404.992315                 0.396100                0.359772         135.077622            2       True         40
# 37        NeuralNetTorch_BAG_L1     -29.625461 -29.350895  mean_absolute_error        1.776888       1.409798   207.388699                 1.776888                1.409798         207.388699            1       True          8
# 38    NeuralNetTorch_r79_BAG_L2     -29.639308 -33.944649  mean_absolute_error       11.444257      11.863515  4429.288842                 1.506083                1.418187         159.374149            2       True         27
# 39         ExtraTreesMSE_BAG_L1     -29.875802 -29.633209  mean_absolute_error        0.390640       2.119528    75.663586                 0.390640                2.119528          75.663586            1       True          5
# 40  NeuralNetFastAI_r102_BAG_L2     -31.493590 -37.069309  mean_absolute_error       10.216919      10.694517  4318.305394                 0.278744                0.249189          48.390701            2       True         36
# 41       RandomForestMSE_BAG_L1     -31.564287 -29.646177  mean_absolute_error        0.452899       2.104383    93.233453                 0.452899                2.104383          93.233453            1       True          3
# 	1	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: False)
# 	9932s	 = DyStack   runtime |	29668s	 = Remaining runtime
# Starting main fit with num_stack_levels=1.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=1)`
# Beginning AutoGluon training ... Time limit = 29668s
# AutoGluon will save models to "/kaggle/working/AutogluonModels/ag-20250914_104327"
# Train Data Rows:    2662
# Train Data Columns: 2317
# Label Column:       Tm
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    28951.07 MB
# 	Train Data (Original)  Memory Usage: 47.06 MB (0.2% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 1885 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Useless Original Features (Count: 87): ['Group 12', 'Group 28', 'Group 46', 'Group 67', 'Group 73', 'Group 74', 'Group 75', 'Group 84', 'Group 85', 'Group 88', 'Group 90', 'Group 101', 'Group 102', 'Group 104', 'Group 150', 'Group 152', 'Group 155', 'Group 158', 'Group 160', 'Group 167', 'Group 183', 'Group 194', 'Group 198', 'Group 206', 'Group 207', 'Group 208', 'Group 209', 'Group 212', 'Group 213', 'Group 214', 'Group 215', 'Group 216', 'Group 217', 'Group 218', 'Group 245', 'Group 247', 'Group 248', 'Group 250', 'Group 252', 'Group 253', 'Group 264', 'Group 280', 'Group 281', 'Group 282', 'Group 285', 'Group 294', 'Group 303', 'Group 306', 'Group 307', 'Group 308', 'Group 309', 'Group 312', 'Group 313', 'Group 316', 'Group 317', 'Group 340', 'Group 342', 'Group 345', 'Group 347', 'Group 348', 'Group 349', 'Group 350', 'Group 352', 'Group 355', 'Group 356', 'Group 357', 'Group 358', 'Group 360', 'Group 363', 'Group 371', 'Group 376', 'Group 377', 'Group 383', 'Group 384', 'Group 385', 'Group 390', 'Group 397', 'Group 399', 'Group 411', 'Group 413', 'Group 417', 'Group 419', 'Group 420', 'Group 421', 'Group 422', 'Group 423', 'Group 424']
# 		These features carry no predictive signal and should be manually investigated.
# 		This is typically a feature which has the same value for all rows.
# 		These features do not need to be present at inference time.
# 	Unused Original Features (Count: 37): ['Group 386', 'Morgan_R4_76', 'Morgan_R3_490', 'fr_phos_ester', 'fr_Nhpyrrole', 'MACCS_60', 'FG_Ether', 'MACCS_127', 'Morgan_R3_49', 'fr_COO2', 'fr_COO', 'NumAmideBonds', 'fr_isocyan', 'fr_ester', 'FG_Benzene', 'FG_Carbonyl', 'Morgan_R4_124', 'Morgan_R4_310', 'Morgan_R4_331', 'Morgan_R3_271', 'Morgan_R3_221', 'MACCS_40', 'Morgan_R4_233', 'fr_azo', 'Morgan_R3_282', 'MaxAbsEStateIndex', 'NumAtomStereoCenters', 'Morgan_R3_142', 'Morgan_R3_131', 'Morgan_R4_289', 'Morgan_R3_79', 'Morgan_R3_337', 'Morgan_R3_259', 'Morgan_R4_175', 'MACCS_13', 'NumAromaticCarbocycles', 'fr_nitroso']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('float', []) :  1 | ['MaxAbsEStateIndex']
# 		('int', [])   : 36 | ['Group 386', 'Morgan_R4_76', 'Morgan_R3_490', 'fr_phos_ester', 'fr_Nhpyrrole', ...]
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) :   97 | ['SMR_VSA7', 'PEOE_VSA1', 'MolMR', 'AvgIpc', 'EState_VSA5', ...]
# 		('int', [])   : 2096 | ['Group 1', 'Group 2', 'Group 3', 'Group 4', 'Group 5', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     :   97 | ['SMR_VSA7', 'PEOE_VSA1', 'MolMR', 'AvgIpc', 'EState_VSA5', ...]
# 		('int', [])       :  237 | ['Group 1', 'Group 2', 'Group 3', 'Group 4', 'Group 5', ...]
# 		('int', ['bool']) : 1859 | ['Group 10', 'Group 11', 'Group 14', 'Group 24', 'Group 26', ...]
# 	42.4s = Fit runtime
# 	2193 features in original data used to generate 2193 features in processed data.
# 	Train Data (Processed) Memory Usage: 11.50 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 42.72s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (110 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 106 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 19745.49s of the 29625.63s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# [1000]	valid_set's l1: 26.8459
# [1000]	valid_set's l1: 24.3581
# [1000]	valid_set's l1: 27.82
# [2000]	valid_set's l1: 27.6615
# [3000]	valid_set's l1: 27.5826
# [4000]	valid_set's l1: 27.5738
# [5000]	valid_set's l1: 27.564
# [1000]	valid_set's l1: 25.371
# [2000]	valid_set's l1: 25.0584
# [3000]	valid_set's l1: 24.9303
# [4000]	valid_set's l1: 24.8854
# [5000]	valid_set's l1: 24.8647
# [6000]	valid_set's l1: 24.8469
# [7000]	valid_set's l1: 24.8378
# [8000]	valid_set's l1: 24.8312
# [9000]	valid_set's l1: 24.8264
# [10000]	valid_set's l1: 24.823
# [1000]	valid_set's l1: 28.5288
# [2000]	valid_set's l1: 28.4633
# 	-26.7544	 = Validation score   (-mean_absolute_error)
# 	151.9s	 = Training   runtime
# 	0.92s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 19590.16s of the 29470.30s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# [1000]	valid_set's l1: 25.9217
# 	-27.7538	 = Validation score   (-mean_absolute_error)
# 	62.81s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 19525.79s of the 29405.93s of remaining time.
# 	-29.9562	 = Validation score   (-mean_absolute_error)
# 	113.11s	 = Training   runtime
# 	2.42s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 19409.49s of the 29289.64s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-26.818	 = Validation score   (-mean_absolute_error)
# 	1404.5s	 = Training   runtime
# 	1.05s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 18002.78s of the 27882.92s of remaining time.
# 	-29.0284	 = Validation score   (-mean_absolute_error)
# 	93.29s	 = Training   runtime
# 	2.45s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 17906.24s of the 27786.38s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-30.0283	 = Validation score   (-mean_absolute_error)
# 	76.49s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 17828.12s of the 27708.26s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-27.8024	 = Validation score   (-mean_absolute_error)
# 	502.42s	 = Training   runtime
# 	0.5s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 17323.79s of the 27203.93s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-29.5621	 = Validation score   (-mean_absolute_error)
# 	224.99s	 = Training   runtime
# 	1.42s	 = Validation runtime
# ...
# 	-26.1102	 = Validation score   (-mean_absolute_error)
# 	45.13s	 = Training   runtime
# 	2.37s	 = Validation runtime
# Fitting model: CatBoost_r69_BAG_L2 ... Training model for up to 5613.67s of the 5613.62s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-25.8213	 = Validation score   (-mean_absolute_error)
# 	102.44s	 = Training   runtime
# 	0.67s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r103_BAG_L2 ... Training model for up to 5509.50s of the 5509.44s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# No improvement since epoch 22: early stopping
# No improvement since epoch 20: early stopping
# 	-30.3765	 = Validation score   (-mean_absolute_error)
# 	138.08s	 = Training   runtime
# 	0.32s	 = Validation runtime
# Fitting model: NeuralNetTorch_r14_BAG_L2 ... Training model for up to 5369.68s of the 5369.62s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-34.8166	 = Validation score   (-mean_absolute_error)
# 	205.31s	 = Training   runtime
# 	1.43s	 = Validation runtime
# Fitting model: LightGBM_r161_BAG_L2 ... Training model for up to 5161.79s of the 5161.73s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-27.0902	 = Validation score   (-mean_absolute_error)
# 	152.07s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r143_BAG_L2 ... Training model for up to 5007.43s of the 5007.37s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-29.2188	 = Validation score   (-mean_absolute_error)
# 	63.4s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: CatBoost_r70_BAG_L2 ... Training model for up to 4942.36s of the 4942.31s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-25.7688	 = Validation score   (-mean_absolute_error)
# 	260.5s	 = Training   runtime
# 	1.12s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r156_BAG_L2 ... Training model for up to 4679.67s of the 4679.61s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# No improvement since epoch 14: early stopping
# 	-31.9222	 = Validation score   (-mean_absolute_error)
# 	84.88s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: LightGBM_r196_BAG_L2 ... Training model for up to 4593.01s of the 4592.96s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# [1000]	valid_set's l1: 28.0073
# [1000]	valid_set's l1: 27.8224
# [1000]	valid_set's l1: 28.3095
# [1000]	valid_set's l1: 29.4192
# [1000]	valid_set's l1: 26.1969
# [1000]	valid_set's l1: 26.8801
# 	-27.1879	 = Validation score   (-mean_absolute_error)
# 	188.48s	 = Training   runtime
# 	0.44s	 = Validation runtime
# Fitting model: RandomForest_r39_BAG_L2 ... Training model for up to 4400.94s of the 4400.89s of remaining time.
# 	-26.2907	 = Validation score   (-mean_absolute_error)
# 	66.78s	 = Training   runtime
# 	2.42s	 = Validation runtime
# Fitting model: CatBoost_r167_BAG_L2 ... Training model for up to 4331.10s of the 4331.05s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-26.2465	 = Validation score   (-mean_absolute_error)
# 	177.32s	 = Training   runtime
# 	0.65s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r95_BAG_L2 ... Training model for up to 4152.08s of the 4152.02s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-32.1883	 = Validation score   (-mean_absolute_error)
# 	140.78s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: NeuralNetTorch_r41_BAG_L2 ... Training model for up to 4009.53s of the 4009.47s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-31.943	 = Validation score   (-mean_absolute_error)
# 	84.8s	 = Training   runtime
# 	1.43s	 = Validation runtime
# Fitting model: XGBoost_r98_BAG_L2 ... Training model for up to 3922.13s of the 3922.08s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-26.3685	 = Validation score   (-mean_absolute_error)
# 	334.84s	 = Training   runtime
# 	1.42s	 = Validation runtime
# Fitting model: LightGBM_r15_BAG_L2 ... Training model for up to 3584.62s of the 3584.57s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-26.6425	 = Validation score   (-mean_absolute_error)
# 	35.1s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: NeuralNetTorch_r158_BAG_L2 ... Training model for up to 3548.29s of the 3548.24s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-32.8711	 = Validation score   (-mean_absolute_error)
# 	263.74s	 = Training   runtime
# 	1.44s	 = Validation runtime
# Fitting model: CatBoost_r86_BAG_L2 ... Training model for up to 3281.87s of the 3281.81s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-26.0259	 = Validation score   (-mean_absolute_error)
# 	368.5s	 = Training   runtime
# 	1.03s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r37_BAG_L2 ... Training model for up to 2911.26s of the 2911.21s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# No improvement since epoch 16: early stopping
# 	-30.1211	 = Validation score   (-mean_absolute_error)
# 	92.21s	 = Training   runtime
# 	0.27s	 = Validation runtime
# Fitting model: NeuralNetTorch_r197_BAG_L2 ... Training model for up to 2817.37s of the 2817.31s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-226.0482	 = Validation score   (-mean_absolute_error)
# 	76.0s	 = Training   runtime
# 	1.43s	 = Validation runtime
# Fitting model: CatBoost_r49_BAG_L2 ... Training model for up to 2738.78s of the 2738.72s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-25.6951	 = Validation score   (-mean_absolute_error)
# 	67.36s	 = Training   runtime
# 	1.36s	 = Validation runtime
# Fitting model: ExtraTrees_r49_BAG_L2 ... Training model for up to 2669.01s of the 2668.96s of remaining time.
# 	-27.1064	 = Validation score   (-mean_absolute_error)
# 	3.5s	 = Training   runtime
# 	2.45s	 = Validation runtime
# Fitting model: LightGBM_r143_BAG_L2 ... Training model for up to 2662.28s of the 2662.22s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-27.1336	 = Validation score   (-mean_absolute_error)
# 	97.27s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: RandomForest_r127_BAG_L2 ... Training model for up to 2563.44s of the 2563.39s of remaining time.
# 	-26.3395	 = Validation score   (-mean_absolute_error)
# 	54.43s	 = Training   runtime
# 	2.4s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r134_BAG_L2 ... Training model for up to 2505.99s of the 2505.94s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-30.7653	 = Validation score   (-mean_absolute_error)
# 	141.96s	 = Training   runtime
# 	0.32s	 = Validation runtime
# Fitting model: RandomForest_r34_BAG_L2 ... Training model for up to 2362.22s of the 2362.17s of remaining time.
# 	-26.3634	 = Validation score   (-mean_absolute_error)
# 	16.57s	 = Training   runtime
# 	2.25s	 = Validation runtime
# Fitting model: LightGBM_r94_BAG_L2 ... Training model for up to 2342.79s of the 2342.73s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-26.7675	 = Validation score   (-mean_absolute_error)
# 	22.22s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: NeuralNetTorch_r143_BAG_L2 ... Training model for up to 2319.39s of the 2319.33s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-32.721	 = Validation score   (-mean_absolute_error)
# 	266.85s	 = Training   runtime
# 	1.46s	 = Validation runtime
# Fitting model: CatBoost_r128_BAG_L2 ... Training model for up to 2049.88s of the 2049.82s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-26.0695	 = Validation score   (-mean_absolute_error)
# 	533.86s	 = Training   runtime
# 	1.11s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r111_BAG_L2 ... Training model for up to 1513.81s of the 1513.75s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# No improvement since epoch 0: early stopping
# 	-48.1441	 = Validation score   (-mean_absolute_error)
# 	47.29s	 = Training   runtime
# 	0.27s	 = Validation runtime
# Fitting model: NeuralNetTorch_r31_BAG_L2 ... Training model for up to 1464.81s of the 1464.75s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-52.8869	 = Validation score   (-mean_absolute_error)
# 	86.92s	 = Training   runtime
# 	1.43s	 = Validation runtime
# Fitting model: ExtraTrees_r4_BAG_L2 ... Training model for up to 1375.29s of the 1375.24s of remaining time.
# 	-26.1542	 = Validation score   (-mean_absolute_error)
# 	19.28s	 = Training   runtime
# 	2.25s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r65_BAG_L2 ... Training model for up to 1353.15s of the 1353.09s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# No improvement since epoch 4: early stopping
# 	-35.2394	 = Validation score   (-mean_absolute_error)
# 	72.2s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r88_BAG_L2 ... Training model for up to 1279.26s of the 1279.21s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# No improvement since epoch 0: early stopping
# No improvement since epoch 29: early stopping
# 	-37.7063	 = Validation score   (-mean_absolute_error)
# 	85.69s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitting model: LightGBM_r30_BAG_L2 ... Training model for up to 1191.92s of the 1191.87s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-26.8975	 = Validation score   (-mean_absolute_error)
# 	68.0s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: XGBoost_r49_BAG_L2 ... Training model for up to 1122.16s of the 1122.10s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-26.5923	 = Validation score   (-mean_absolute_error)
# 	103.04s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: CatBoost_r5_BAG_L2 ... Training model for up to 1017.81s of the 1017.76s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-25.7311	 = Validation score   (-mean_absolute_error)
# 	75.02s	 = Training   runtime
# 	0.66s	 = Validation runtime
# Fitting model: NeuralNetTorch_r87_BAG_L2 ... Training model for up to 941.01s of the 940.96s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-31.6425	 = Validation score   (-mean_absolute_error)
# 	97.14s	 = Training   runtime
# 	1.43s	 = Validation runtime
# Fitting model: NeuralNetTorch_r71_BAG_L2 ... Training model for up to 841.28s of the 841.23s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-226.0482	 = Validation score   (-mean_absolute_error)
# 	73.93s	 = Training   runtime
# 	1.42s	 = Validation runtime
# Fitting model: CatBoost_r143_BAG_L2 ... Training model for up to 764.77s of the 764.72s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-25.9695	 = Validation score   (-mean_absolute_error)
# 	189.83s	 = Training   runtime
# 	1.35s	 = Validation runtime
# Fitting model: ExtraTrees_r178_BAG_L2 ... Training model for up to 572.51s of the 572.46s of remaining time.
# 	-26.1567	 = Validation score   (-mean_absolute_error)
# 	33.64s	 = Training   runtime
# 	2.31s	 = Validation runtime
# Fitting model: RandomForest_r166_BAG_L2 ... Training model for up to 535.91s of the 535.86s of remaining time.
# 	-28.3034	 = Validation score   (-mean_absolute_error)
# 	2.11s	 = Training   runtime
# 	2.37s	 = Validation runtime
# Fitting model: XGBoost_r31_BAG_L2 ... Training model for up to 530.62s of the 530.57s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-26.2496	 = Validation score   (-mean_absolute_error)
# 	113.16s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: NeuralNetTorch_r185_BAG_L2 ... Training model for up to 416.10s of the 416.05s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	Ran out of time, stopping training early. (Stopping on epoch 109)
# 	-32.1885	 = Validation score   (-mean_absolute_error)
# 	187.85s	 = Training   runtime
# 	1.47s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r160_BAG_L2 ... Training model for up to 225.59s of the 225.54s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-33.8042	 = Validation score   (-mean_absolute_error)
# 	91.18s	 = Training   runtime
# 	0.34s	 = Validation runtime
# Fitting model: CatBoost_r60_BAG_L2 ... Training model for up to 132.68s of the 132.62s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-25.7622	 = Validation score   (-mean_absolute_error)
# 	92.32s	 = Training   runtime
# 	1.36s	 = Validation runtime
# Fitting model: RandomForest_r15_BAG_L2 ... Training model for up to 37.94s of the 37.88s of remaining time.
# 	-26.2642	 = Validation score   (-mean_absolute_error)
# 	53.25s	 = Training   runtime
# 	2.26s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 987.91s of the -18.43s of remaining time.
# 	Ensemble Weights: {'LightGBM_r96_BAG_L1': 0.227, 'CatBoost_r49_BAG_L2': 0.227, 'LightGBM_r188_BAG_L1': 0.182, 'CatBoost_r137_BAG_L2': 0.182, 'NeuralNetFastAI_r191_BAG_L1': 0.091, 'NeuralNetTorch_r22_BAG_L2': 0.091}
# 	-25.3434	 = Validation score   (-mean_absolute_error)
# 	0.13s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 29687.01s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 52.3 rows/s (333 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/kaggle/working/AutogluonModels/ag-20250914_104327")

# %%
predictor.leaderboard(silent=True).style.background_gradient(subset=['score_val'], cmap='RdYlGn')
# Out:
# <style type="text/css">
# #T_f8f69_row0_col1, #T_f8f69_row1_col1, #T_f8f69_row2_col1, #T_f8f69_row3_col1, #T_f8f69_row4_col1, #T_f8f69_row5_col1, #T_f8f69_row6_col1, #T_f8f69_row7_col1, #T_f8f69_row8_col1, #T_f8f69_row9_col1, #T_f8f69_row10_col1, #T_f8f69_row11_col1, #T_f8f69_row12_col1, #T_f8f69_row13_col1, #T_f8f69_row14_col1, #T_f8f69_row15_col1, #T_f8f69_row16_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_f8f69_row17_col1, #T_f8f69_row18_col1, #T_f8f69_row19_col1, #T_f8f69_row20_col1, #T_f8f69_row21_col1, #T_f8f69_row22_col1, #T_f8f69_row23_col1, #T_f8f69_row24_col1, #T_f8f69_row25_col1, #T_f8f69_row26_col1, #T_f8f69_row27_col1, #T_f8f69_row28_col1, #T_f8f69_row29_col1, #T_f8f69_row30_col1, #T_f8f69_row31_col1, #T_f8f69_row32_col1, #T_f8f69_row33_col1, #T_f8f69_row34_col1, #T_f8f69_row35_col1, #T_f8f69_row36_col1, #T_f8f69_row37_col1, #T_f8f69_row38_col1, #T_f8f69_row39_col1, #T_f8f69_row40_col1, #T_f8f69_row41_col1, #T_f8f69_row42_col1, #T_f8f69_row43_col1, #T_f8f69_row44_col1, #T_f8f69_row45_col1, #T_f8f69_row46_col1 {
#   background-color: #016a38;
#   color: #f1f1f1;
# }
# #T_f8f69_row47_col1, #T_f8f69_row48_col1, #T_f8f69_row49_col1, #T_f8f69_row50_col1, #T_f8f69_row51_col1, #T_f8f69_row52_col1, #T_f8f69_row53_col1, #T_f8f69_row54_col1, #T_f8f69_row55_col1, #T_f8f69_row56_col1, #T_f8f69_row57_col1, #T_f8f69_row58_col1 {
#   background-color: #026c39;
#   color: #f1f1f1;
# }
# #T_f8f69_row59_col1, #T_f8f69_row60_col1, #T_f8f69_row61_col1, #T_f8f69_row62_col1, #T_f8f69_row63_col1, #T_f8f69_row64_col1, #T_f8f69_row65_col1 {
#   background-color: #036e3a;
#   color: #f1f1f1;
# }
# #T_f8f69_row66_col1, #T_f8f69_row67_col1, #T_f8f69_row68_col1, #T_f8f69_row69_col1 {
#   background-color: #04703b;
#   color: #f1f1f1;
# }
# #T_f8f69_row70_col1, #T_f8f69_row71_col1, #T_f8f69_row72_col1, #T_f8f69_row73_col1, #T_f8f69_row74_col1, #T_f8f69_row75_col1 {
#   background-color: #05713c;
#   color: #f1f1f1;
# }
# #T_f8f69_row76_col1, #T_f8f69_row77_col1, #T_f8f69_row78_col1, #T_f8f69_row79_col1 {
#   background-color: #06733d;
#   color: #f1f1f1;
# }
# #T_f8f69_row80_col1, #T_f8f69_row81_col1, #T_f8f69_row82_col1, #T_f8f69_row83_col1, #T_f8f69_row84_col1 {
#   background-color: #08773f;
#   color: #f1f1f1;
# }
# #T_f8f69_row85_col1, #T_f8f69_row86_col1, #T_f8f69_row87_col1, #T_f8f69_row88_col1, #T_f8f69_row89_col1 {
#   background-color: #097940;
#   color: #f1f1f1;
# }
# #T_f8f69_row90_col1, #T_f8f69_row91_col1, #T_f8f69_row92_col1 {
#   background-color: #0a7b41;
#   color: #f1f1f1;
# }
# #T_f8f69_row93_col1, #T_f8f69_row94_col1 {
#   background-color: #0c7f43;
#   color: #f1f1f1;
# }
# #T_f8f69_row95_col1 {
#   background-color: #0d8044;
#   color: #f1f1f1;
# }
# #T_f8f69_row96_col1 {
#   background-color: #0e8245;
#   color: #f1f1f1;
# }
# #T_f8f69_row97_col1 {
#   background-color: #0f8446;
#   color: #f1f1f1;
# }
# #T_f8f69_row98_col1 {
#   background-color: #249d53;
#   color: #f1f1f1;
# }
# #T_f8f69_row99_col1 {
#   background-color: #36a657;
#   color: #f1f1f1;
# }
# #T_f8f69_row100_col1, #T_f8f69_row101_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f8f69">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f8f69_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_f8f69_level0_col1" class="col_heading level0 col1" >score_val</th>
#       <th id="T_f8f69_level0_col2" class="col_heading level0 col2" >eval_metric</th>
#       <th id="T_f8f69_level0_col3" class="col_heading level0 col3" >pred_time_val</th>
#       <th id="T_f8f69_level0_col4" class="col_heading level0 col4" >fit_time</th>
#       <th id="T_f8f69_level0_col5" class="col_heading level0 col5" >pred_time_val_marginal</th>
#       <th id="T_f8f69_level0_col6" class="col_heading level0 col6" >fit_time_marginal</th>
#       <th id="T_f8f69_level0_col7" class="col_heading level0 col7" >stack_level</th>
#       <th id="T_f8f69_level0_col8" class="col_heading level0 col8" >can_infer</th>
#       <th id="T_f8f69_level0_col9" class="col_heading level0 col9" >fit_order</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f8f69_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f8f69_row0_col0" class="data row0 col0" >WeightedEnsemble_L2</td>
#       <td id="T_f8f69_row0_col1" class="data row0 col1" >-25.328543</td>
#       <td id="T_f8f69_row0_col2" class="data row0 col2" >mean_absolute_error</td>
#       <td id="T_f8f69_row0_col3" class="data row0 col3" >6.369106</td>
#       <td id="T_f8f69_row0_col4" class="data row0 col4" >3267.496855</td>
#       <td id="T_f8f69_row0_col5" class="data row0 col5" >0.000726</td>
#       <td id="T_f8f69_row0_col6" class="data row0 col6" >0.128565</td>
#       <td id="T_f8f69_row0_col7" class="data row0 col7" >2</td>
#       <td id="T_f8f69_row0_col8" class="data row0 col8" >True</td>
#       <td id="T_f8f69_row0_col9" class="data row0 col9" >24</td>
#     </tr>
#     <tr>
#       <th id="T_f8f69_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f8f69_row1_col0" class="data row1 col0" >WeightedEnsemble_L3</td>
#       <td id="T_f8f69_row1_col1" class="data row1 col1" >-25.343359</td>
#       <td id="T_f8f69_row1_col2" class="data row1 col2" >mean_absolute_error</td>
#       <td id="T_f8f69_row1_col3" class="data row1 col3" >35.614173</td>
#       <td id="T_f8f69_row1_col4" class="data row1 col4" >11214.226656</td>
#       <td id="T_f8f69_row1_col5" class="data row1 col5" >0.000708</td>
#       <td id="T_f8f69_row1_col6" class="data row1 col6" >0.133409</td>
#       <td id="T_f8f69_row1_col7" class="data row1 col7" >3</td>
#       <td id="T_f8f69_row1_col8" class="data row1 col8" >True</td>
#       <td id="T_f8f69_row1_col9" class="data row1 col9" >102</td>
#     </tr>
#     <tr>
#       <th id="T_f8f69_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f8f69_row2_col0" class="data row2 col0" >CatBoost_r49_BAG_L2</td>
#       <td id="T_f8f69_row2_col1" class="data row2 col1" >-25.695109</td>
#       <td id="T_f8f69_row2_col2" class="data row2 col2" >mean_absolute_error</td>
#       <td id="T_f8f69_row2_col3" class="data row2 col3" >32.809289</td>
#       <td id="T_f8f69_row2_col4" class="data row2 col4" >11032.828903</td>
#       <td id="T_f8f69_row2_col5" class="data row2 col5" >1.357398</td>
#       <td id="T_f8f69_row2_col6" class="data row2 col6" >67.356742</td>
#       <td id="T_f8f69_row2_col7" class="data row2 col7" >2</td>
#       <td id="T_f8f69_row2_col8" class="data row2 col8" >True</td>
#       <td id="T_f8f69_row2_col9" class="data row2 col9" >75</td>
#     </tr>
#     <tr>
#       <th id="T_f8f69_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f8f69_row3_col0" class="data row3 col0" >CatBoost_r137_BAG_L2</td>
#       <td id="T_f8f69_row3_col1" class="data row3 col1" >-25.721848</td>
#       <td id="T_f8f69_row3_col2" class="data row3 col2" >mean_absolute_error</td>
#       <td id="T_f8f69_row3_col3" class="data row3 col3" >32.803008</td>
#       <td id="T_f8f69_row3_col4" class="data row3 col4" >11035.824238</td>
#       <td id="T_f8f69_row3_col5" class="data row3 col5" >1.351117</td>
#       <td id="T_f8f69_row3_col6" class="data row3 col6" >70.352077</td>
#       <td id="T_f8f69_row3_col7" class="data row3 col7" >2</td>
#       <td id="T_f8f69_row3_col8" class="data row3 col8" >True</td>
#       <td id="T_f8f69_row3_col9" class="data row3 col9" >43</td>
#     </tr>
#     <tr>
#       <th id="T_f8f69_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f8f69_row4_col0" class="data row4 col0" >CatBoost_r5_BAG_L2</td>
#       <td id="T_f8f69_row4_col1" class="data row4 col1" >-25.731062</td>
#       <td id="T_f8f69_row4_col2" class="data row4 col2" >mean_absolute_error</td>
#       <td id="T_f8f69_row4_col3" class="data row4 col3" >32.110854</td>
#       <td id="T_f8f69_row4_col4" class="data row4 col4" >11040.489306</td>
#       <td id="T_f8f69_row4_col5" class="data row4 col5" >0.658962</td>
#       <td id="T_f8f69_row4_col6" class="data row4 col6" >75.017145</td>
#       <td id="T_f8f69_row4_col7" class="data row4 col7" >2</td>
#       <td id="T_f8f69_row4_col8" class="data row4 col8" >True</td>
#       <

# %%
print("\nGenerating test predictions...")
test_preds = predictor.predict(test_ag)
# Out:
# Generating test predictions...

# %% [markdown]
# <!-- ================= H2 HEADER: Submission File Creation ================= -->
# <div style="border-radius:25px 70px; padding:14px 18px; margin:10px 0;
#             font-family:'Quicksand', sans-serif; background:#24a695; overflow:hidden;">
#   <div style="text-align:center; color:#ffffff; font-size:150%; margin:0; padding:0;">
#     <b><h2 style="margin:0; color:#ffffff;">Submission File Creation</h2></b>
#   </div>
# </div>
#
# <!-- ================= BADGES: Submission Steps ================= -->
# <div style="display:flex; gap:10px; flex-wrap:wrap; justify-content:center; margin:12px 0; font-family:Inter, system-ui, 'Segoe UI', Roboto, Arial, sans-serif;">
#   <span style="background:#e2e8f0; color:#0f172a; padding:6px 14px; border-radius:999px; font-size:13px; border:1px solid #cbd5e1;">Prepare Submission DataFrame</span>
#   <span style="background:#dbeafe; color:#1e3a8a; padding:6px 14px; border-radius:999px; font-size:13px; border:1px solid #bfdbfe;">Save CSV File</span>
#
#
# </div>

# %%
submission = sample_submission.copy()
submission[TARGET] = test_preds
submission.to_csv("submission.csv", index=False)
print("\nSubmission file 'submission.csv' created successfully.")

# End timing the script
end_time = time.time()
print(f"\nTotal script execution time: {end_time - start_time:.2f} seconds")

submission.head()
# Out:
# Submission file 'submission.csv' created successfully.
#
# Total script execution time: 39699.07 seconds
#      id          Tm
# 0  1022  355.054565
# 1  1146  329.085510
# 2    79  199.289200
# 3  2279  207.864136
# 4  1342  230.985397

# %%
shutil.rmtree("AutogluonModels")

# %% [markdown]
# <!-- ================= HEADER + BADGES MERGED ================= -->
# <div style="border-radius:25px 70px; padding:14px 18px; margin:0 0 18px 0; font-family:'Quicksand', sans-serif; background:#24a695; overflow:hidden;">
#   <div style="text-align:center; color:#ffffff; font-size:170%; margin:0; padding:0;">
#     <b><h3 style="text-align:center; color:#ffffff; font-size:150%; margin:0; padding:0;">Thank You</h3></b>
#   </div>
# </div>
#
# <div style="display:flex; gap:8px; flex-wrap:wrap; margin-top:10px; font-family:Inter, system-ui, 'Segoe UI', Roboto, Arial, sans-serif;">
#   <a href="#Thermophysical-Property:-Melting-Point" style="margin-left:auto; font-size:12px; color:red; text-decoration:none;">Back to top ↑</a>
# </div>
