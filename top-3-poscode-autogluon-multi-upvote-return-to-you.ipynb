# %% [markdown]
# <a href="https://www.kaggle.com/code/daniyalatta/autogluon-multi-1-upvote-1-motivations?scriptVersionId=261488603" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# <div style="text-align:center; border-radius:25px 70px; padding:15px; color:#ffffff; margin:0; font-size:180%; font-family:'Quicksand', sans-serif; background:#24a695; overflow:hidden">
#   <b>
#     <h3  style="font-weight:150;color:#ffffff; font-size:120%">🚀 Your upvote can motivate me to share more useful notebooks!</h3>
#     <h4 style=" font-weight:120; color:#ffffff; font-size:100%">Rate My Notebook Design</h4>
#   </b>
# </div>

# %% [markdown]
# <!-- ================= HEADER ================= -->
# <div style="border-radius:25px 70px; padding:14px 18px; margin:0 0 18px 0;
#             font-family:'Quicksand', sans-serif; background:#24a695; overflow:hidden;">
#   <div style="text-align:center; color:#ffffff; font-size:150%; margin:0; padding:0;">
#     <b><h1 style="margin:0; color:#ffffff;">Thermophysical Property: Melting Point</h1></b>
#   </div>
# </div>
#
# <!-- ================= TABLE OF CONTENTS HEADER ================= -->
# <div style="border-radius:25px 70px; padding:10px 16px; margin:10px 0; font-family:'Quicksand', sans-serif; background:#24a695; overflow:hidden;">
#   <div style="text-align:center; color:#ffffff; font-size:140%; margin:0; padding:0;">
#     <b><h2 style="margin:0; color:#ffffff;">Table of Contents</h2></b>
#   </div>
# </div>
#
# <!-- ================= TABLE OF CONTENTS LIST ================= -->
# <div style="background:#24a695; padding:12px 16px; border-radius:16px; font-family:Inter, system-ui, 'Segoe UI', Roboto, Arial, sans-serif; margin-bottom:20px;">
#   <ol style="margin:0; font-size:18px; padding-left:22px; line-height:1.7; color:#ffffff;">
#     <li><a href="#Setup-and-Data-Loading" style="color:#ffffff; text-decoration:none;">Setup and Data Loading</a></li>
#     <li><a href="#RDKit-Feature-Generation-Function" style="color:#ffffff; text-decoration:none;">RDKit Feature Generation Functions</a></li>
#     <li><a href="#Execute-Feature-Generation" style="color:#ffffff; text-decoration:none;">Execute Feature Generation</a></li>
#     <li><a href="#AutoGluon-Training-and-Prediction" style="color:#ffffff; text-decoration:none;">AutoGluon Training and Prediction</a></li>
#     <li><a href="#Submission-File-Creation-and-Final-Timing" style="color:#ffffff; text-decoration:none;">Submission File Creation and Final Timing</a></li>
#   </ol>
# </div>

# %% [markdown]
# ![](https://www.googleapis.com/download/storage/v1/b/kaggle-forum-message-attachments/o/inbox%2F14134958%2F17b6a7f04d41676af54132813a0b64ac%2FThermal-Properties-of-matter-.webp?generation=1757037113142785&alt=media)

# %%
pip install rdkit
# Out:
# Collecting rdkit
#   Downloading rdkit-2025.3.6-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from rdkit) (1.26.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from rdkit) (11.2.1)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->rdkit) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->rdkit) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->rdkit) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->rdkit) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->rdkit) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->rdkit) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->rdkit) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->rdkit) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->rdkit) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->rdkit) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->rdkit) (2024.2.0)
# Downloading rdkit-2025.3.6-cp311-cp311-manylinux_2_28_x86_64.whl (36.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.2/36.2 MB 42.3 MB/s eta 0:00:00
# Installing collected packages: rdkit
# Successfully installed rdkit-2025.3.6
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install autogluon.tabular scikit-learn==1.5.2
# Out:
# Collecting autogluon.tabular
#   Downloading autogluon.tabular-1.4.0-py3-none-any.whl.metadata (16 kB)
# Collecting scikit-learn==1.5.2
#   Downloading scikit_learn-1.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.2) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.2) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.2) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.2) (3.6.0)
# Requirement already satisfied: pandas<2.4.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from autogluon.tabular) (2.2.3)
# Requirement already satisfied: networkx<4,>=3.0 in /usr/local/lib/python3.11/dist-packages (from autogluon.tabular) (3.5)
# Collecting autogluon.core==1.4.0 (from autogluon.tabular)
#   Downloading autogluon.core-1.4.0-py3-none-any.whl.metadata (12 kB)
# Collecting autogluon.features==1.4.0 (from autogluon.tabular)
#   Downloading autogluon.features-1.4.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: tqdm<5,>=4.38 in /usr/local/lib/python3.11/dist-packages (from autogluon.core==1.4.0->autogluon.tabular) (4.67.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from autogluon.core==1.4.0->autogluon.tabular) (2.32.4)
# Requirement already satisfied: matplotlib<3.11,>=3.7.0 in /usr/local/lib/python3.11/dist-packages (from autogluon.core==1.4.0->autogluon.tabular) (3.7.2)
# Requirement already satisfied: boto3<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from autogluon.core==1.4.0->autogluon.tabular) (1.39.1)
# Collecting autogluon.common==1.4.0 (from autogluon.core==1.4.0->autogluon.tabular)
#   Downloading autogluon.common-1.4.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pyarrow<21.0.0,>=7.0.0 in /usr/local/lib/python3.11/dist-packages (from autogluon.common==1.4.0->autogluon.core==1.4.0->autogluon.tabular) (19.0.1)
# Requirement already satisfied: psutil<7.1.0,>=5.7.3 in /usr/local/lib/python3.11/dist-packages (from autogluon.common==1.4.0->autogluon.core==1.4.0->autogluon.tabular) (7.0.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.19.5->scikit-learn==1.5.2) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.19.5->scikit-learn==1.5.2) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.19.5->scikit-learn==1.5.2) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.19.5->scikit-learn==1.5.2) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.19.5->scikit-learn==1.5.2) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.19.5->scikit-learn==1.5.2) (2.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas<2.4.0,>=2.0.0->autogluon.tabular) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<2.4.0,>=2.0.0->autogluon.tabular) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<2.4.0,>=2.0.0->autogluon.tabular) (2025.2)
# Requirement already satisfied: botocore<1.40.0,>=1.39.1 in /usr/local/lib/python3.11/dist-packages (from boto3<2,>=1.10->autogluon.core==1.4.0->autogluon.tabular) (1.39.1)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from boto3<2,>=1.10->autogluon.core==1.4.0->autogluon.tabular) (1.0.1)
# Requirement already satisfied: s3transfer<0.14.0,>=0.13.0 in /usr/local/lib/python3.11/dist-packages (from boto3<2,>=1.10->autogluon.core==1.4.0->autogluon.tabular) (0.13.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.4.0->autogluon.tabular) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.4.0->autogluon.tabular) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.4.0->autogluon.tabular) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.4.0->autogluon.tabular) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.4.0->autogluon.tabular) (25.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.4.0->autogluon.tabular) (11.2.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.4.0->autogluon.tabular) (3.0.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas<2.4.0,>=2.0.0->autogluon.tabular) (1.17.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.19.5->scikit-learn==1.5.2) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.19.5->scikit-learn==1.5.2) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.19.5->scikit-learn==1.5.2) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.19.5->scikit-learn==1.5.2) (2024.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->autogluon.core==1.4.0->autogluon.tabular) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->autogluon.core==1.4.0->autogluon.tabular) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->autogluon.core==1.4.0->autogluon.tabular) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->autogluon.core==1.4.0->autogluon.tabular) (2025.6.15)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.19.5->scikit-learn==1.5.2) (2024.2.0)
# Downloading scikit_learn-1.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 64.7 MB/s eta 0:00:00
# Downloading autogluon.tabular-1.4.0-py3-none-any.whl (487 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 487.3/487.3 kB 16.9 MB/s eta 0:00:00
# Downloading autogluon.core-1.4.0-py3-none-any.whl (225 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.1/225.1 kB 8.7 MB/s eta 0:00:00
# Downloading autogluon.features-1.4.0-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.2/64.2 kB 1.8 MB/s eta 0:00:00
# Downloading autogluon.common-1.4.0-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.0/71.0 kB 2.7 MB/s eta 0:00:00
# Installing collected packages: scikit-learn, autogluon.common, autogluon.features, autogluon.core, autogluon.tabular
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed autogluon.common-1.4.0 autogluon.core-1.4.0 autogluon.features-1.4.0 autogluon.tabular-1.4.0 scikit-learn-1.5.2

# %% [markdown]
# <!-- ================= H2 HEADER: Setup and Data Loading ================= -->
# <div style="border-radius:25px 70px; padding:14px 18px; margin:10px 0;
#             font-family:'Quicksand', sans-serif; background:#24a695; overflow:hidden;">
#   <div style="text-align:center; color:#ffffff; font-size:150%; margin:0; padding:0;">
#     <b><h2 style="margin:0; color:#ffffff;">Setup and Data Loading</h2></b>
#   </div>
# </div>
#
# <!-- ================= BADGES: Important Libraries ================= -->
# <div style="display:flex; gap:10px; flex-wrap:wrap; justify-content:center; margin:12px 0; font-family:Inter, system-ui, 'Segoe UI', Roboto, Arial, sans-serif;">
#   <span style="background:#e2e8f0; color:#0f172a; padding:6px 14px; border-radius:999px; font-size:13px; border:1px solid #cbd5e1;">time</span>
#   <span style="background:#dbeafe; color:#1e3a8a; padding:6px 14px; border-radius:999px; font-size:13px; border:1px solid #bfdbfe;">shutil</span>
#   <span style="background:#dcfce7; color:#14532d; padding:6px 14px; border-radius:999px; font-size:13px; border:1px solid #bbf7d0;">warnings</span>
#   <span style="background:#fde68a; color:#92400e; padding:6px 14px; border-radius:999px; font-size:13px; border:1px solid #fcd34d;">numpy</span>
#   <span style="background:#fcd5ce; color:#881337; padding:6px 14px; border-radius:999px; font-size:13px; border:1px solid #fda4af;">pandas</span>
#   <span style="background:#e9d5ff; color:#581c87; padding:6px 14px; border-radius:999px; font-size:13px; border:1px solid #d8b4fe;">tqdm</span>
#   <span style="background:#d1fae5; color:#065f46; padding:6px 14px; border-radius:999px; font-size:13px; border:1px solid #a7f3d0;">multiprocessing</span>
#   <span style="background:#c7d2fe; color:#3730a3; padding:6px 14px; border-radius:999px; font-size:13px; border:1px solid #a5b4fc;">rdkit</span>
#   <span style="background:#fde68a; color:#78350f; padding:6px 14px; border-radius:999px; font-size:13px; border:1px solid #fcd34d;">autogluon.tabular</span>
# </div>

# %%
import time
import shutil
import warnings
import numpy as np
import pandas as pd
from tqdm import tqdm
import multiprocessing
from rdkit import Chem
from rdkit.Chem import Descriptors
from autogluon.tabular import TabularPredictor
from rdkit.Chem.rdMolDescriptors import GetMorganFingerprintAsBitVect, GetMACCSKeysFingerprint

# Ignore all warnings to keep the output clean
warnings.filterwarnings("ignore")

# Start timing the script
start_time = time.time()

print("Loading data...")
try:
    train_df = pd.read_csv("/kaggle/input/melting-point/train.csv")
    test_df = pd.read_csv("/kaggle/input/melting-point/test.csv")
    sample_submission = pd.read_csv("/kaggle/input/melting-point/sample_submission.csv")
    print("Data loaded successfully.")
except FileNotFoundError as e:
    print(f"Error: {e}. Make sure the data is in the correct directory.")
    exit()
# Out:
# Loading data...
# Data loaded successfully.

# %% [markdown]
# <!-- ================= H2 HEADER: RDKit Feature Generation Function ================= -->
# <div style="border-radius:25px 70px; padding:14px 18px; margin:10px 0;
#             font-family:'Quicksand', sans-serif; background:#24a695; overflow:hidden;">
#   <div style="text-align:center; color:#ffffff; font-size:150%; margin:0; padding:0;">
#     <b><h2 style="margin:0; color:#ffffff;">RDKit Feature Generation Function</h2></b>
#   </div>
# </div>
#
# <!-- ================= BADGES: Important RDKit Functions ================= -->
# <div style="display:flex; gap:10px; flex-wrap:wrap; justify-content:center; margin:12px 0; font-family:Inter, system-ui, 'Segoe UI', Roboto, Arial, sans-serif;">
#   <span style="background:#e2e8f0; color:#0f172a; padding:6px 14px; border-radius:999px; font-size:13px; border:1px solid #cbd5e1;">Chem.MolFromSmiles</span>
#   <span style="background:#dbeafe; color:#1e3a8a; padding:6px 14px; border-radius:999px; font-size:13px; border:1px solid #bfdbfe;">Descriptors</span>
#   <span style="background:#dcfce7; color:#14532d; padding:6px 14px; border-radius:999px; font-size:13px; border:1px solid #bbf7d0;">GetMorganFingerprintAsBitVect</span>
#   <span style="background:#fde68a; color:#92400e; padding:6px 14px; border-radius:999px; font-size:13px; border:1px solid #fcd34d;">GetMACCSKeysFingerprint</span>
# </div>

# %%
import numpy as np
import pandas as pd
from rdkit import Chem
from rdkit.Chem import Descriptors, rdMolDescriptors, Crippen
from rdkit.Chem import AllChem
from rdkit.Chem.rdMolDescriptors import GetMorganFingerprintAsBitVect, GetMACCSKeysFingerprint
from tqdm import tqdm
import multiprocessing
import warnings
warnings.filterwarnings('ignore')

# Identify features and target
TARGET = "Tm"
ID_COL = "id"
SMILES_COL = "SMILES"

print(f"Train data shape: {train_df.shape}")
print(f"Test data shape: {test_df.shape}")

class EnhancedMolecularFeatures:
    def __init__(self):
        # No problematic imports - everything works
        pass
    
    def generate_3d_conformer(self, mol):
        """Generate 3D conformer for geometric descriptors"""
        try:
            mol = Chem.AddHs(mol)
            AllChem.EmbedMolecule(mol, randomSeed=42)
            AllChem.MMFFOptimizeMolecule(mol)
            return mol
        except:
            return None
    
    def get_3d_descriptors(self, mol_3d):
        """Calculate 3D geometric descriptors"""
        features = {}
        if mol_3d is None:
            return {f'3D_{key}': 0 for key in [
                'PMI1', 'PMI2', 'PMI3', 'NPR1', 'NPR2', 'RadiusOfGyration',
                'InertialShapeFactor', 'Eccentricity', 'Asphericity', 'SpherocityIndex'
            ]}
        
        try:
            features['3D_PMI1'] = rdMolDescriptors.PMI1(mol_3d)
            features['3D_PMI2'] = rdMolDescriptors.PMI2(mol_3d)
            features['3D_PMI3'] = rdMolDescriptors.PMI3(mol_3d)
            features['3D_NPR1'] = rdMolDescriptors.NPR1(mol_3d)
            features['3D_NPR2'] = rdMolDescriptors.NPR2(mol_3d)
            features['3D_RadiusOfGyration'] = rdMolDescriptors.RadiusOfGyration(mol_3d)
            features['3D_InertialShapeFactor'] = rdMolDescriptors.InertialShapeFactor(mol_3d)
            features['3D_Eccentricity'] = rdMolDescriptors.Eccentricity(mol_3d)
            features['3D_Asphericity'] = rdMolDescriptors.Asphericity(mol_3d)
            features['3D_SpherocityIndex'] = rdMolDescriptors.SpherocityIndex(mol_3d)
        except:
            features = {f'3D_{key}': 0 for key in [
                'PMI1', 'PMI2', 'PMI3', 'NPR1', 'NPR2', 'RadiusOfGyration',
                'InertialShapeFactor', 'Eccentricity', 'Asphericity', 'SpherocityIndex'
            ]}
        
        return features
    
    def get_enhanced_fingerprints(self, mol):
        """Generate enhanced fingerprints"""
        features = {}
        
        # Multiple Morgan fingerprint radii
        for radius in [2, 3, 4]:
            fp = GetMorganFingerprintAsBitVect(mol, radius=radius, nBits=512)
            for i in range(fp.GetNumBits()):
                features[f"Morgan_R{radius}_{i}"] = int(fp.GetBit(i))
        
        # MACCS Keys
        fp_maccs = GetMACCSKeysFingerprint(mol)
        for i in range(fp_maccs.GetNumBits()):
            features[f"MACCS_{i}"] = int(fp_maccs.GetBit(i))
        
        return features
    
    def get_functional_groups(self, mol):
        """Calculate functional group counts"""
        features = {}
        
        # Important patterns for melting point
        patterns = {
            'Hydroxyl': '[OH]',
            'Carbonyl': '[CX3]=[OX1]',
            'Carboxyl': '[CX3](=O)[OX2H1]',
            'Amine': '[NX3;!$(NC=O)]',
            'Ether': '[OD2]([#6])[#6]',
            'Ester': '[#6][CX3](=O)[OX2H0][#6]',
            'Amide': '[NX3][CX3](=[OX1])[#6]',
            'Benzene': 'c1ccccc1',
            'Halogen_F': '[F]',
            'Halogen_Cl': '[Cl]',
            'Halogen_Br': '[Br]'
        }
        
        for name, smarts in patterns.items():
            pattern = Chem.MolFromSmarts(smarts)
            if pattern:
                matches = mol.GetSubstructMatches(pattern)
                features[f'FG_{name}'] = len(matches)
            else:
                features[f'FG_{name}'] = 0
        
        return features
    
    def get_advanced_descriptors(self, mol):
        """Calculate advanced molecular descriptors"""
        features = {}
        
        try:
            features['CrippenLogP'] = Crippen.MolLogP(mol)
            features['CrippenMR'] = Crippen.MolMR(mol)
            features['NumAromaticRings'] = rdMolDescriptors.CalcNumAromaticRings(mol)
            features['NumAliphaticRings'] = rdMolDescriptors.CalcNumAliphaticRings(mol)
            features['FractionCsp3'] = rdMolDescriptors.CalcFractionCsp3(mol)
            features['BertzCT'] = rdMolDescriptors.BertzCT(mol)
            features['BalabanJ'] = rdMolDescriptors.BalabanJ(mol)
            features['Kappa1'] = rdMolDescriptors.Kappa1(mol)
            features['Kappa2'] = rdMolDescriptors.Kappa2(mol)
            features['Chi0'] = rdMolDescriptors.Chi0(mol)
            features['Chi1'] = rdMolDescriptors.Chi1(mol)
        except:
            features = {key: 0 for key in ['CrippenLogP', 'CrippenMR', 'NumAromaticRings', 
                       'NumAliphaticRings', 'FractionCsp3', 'BertzCT', 'BalabanJ',
                       'Kappa1', 'Kappa2', 'Chi0', 'Chi1']}
        
        return features

def generate_enhanced_features_from_smiles(smiles_list):
    """Generate enhanced features from SMILES list"""
    feature_gen = EnhancedMolecularFeatures()
    features = []
    
    for smiles in tqdm(smiles_list, desc="Processing SMILES"):
        mol = Chem.MolFromSmiles(smiles)
        feature_dict = {}
        
        if mol is not None:
            # Original RDKit descriptors - direct calculation (NO IMPORT ISSUES)
            try:
                for desc_name, desc_func in Descriptors.descList:
                    try:
                        feature_dict[desc_name] = desc_func(mol)
                    except:
                        feature_dict[desc_name] = 0
            except:
                pass
            
            # 3D descriptors
            mol_3d = feature_gen.generate_3d_conformer(mol)
            feature_dict.update(feature_gen.get_3d_descriptors(mol_3d))
            
            # Enhanced fingerprints
            feature_dict.update(feature_gen.get_enhanced_fingerprints(mol))
            
            # Functional groups
            feature_dict.update(feature_gen.get_functional_groups(mol))
            
            # Advanced descriptors
            feature_dict.update(feature_gen.get_advanced_descriptors(mol))
        
        features.append(feature_dict)
    
    return features

def parallel_enhanced_feature_generation(smiles_list, num_workers):
    """Generate enhanced features in parallel"""
    chunks = np.array_split(smiles_list, num_workers)
    with multiprocessing.Pool(processes=num_workers) as pool:
        results = pool.map(generate_enhanced_features_from_smiles, chunks)
    
    return [item for sublist in results for item in sublist]

# Get number of cores
num_cores = multiprocessing.cpu_count()
print(f"Using {num_cores} CPU cores for enhanced feature generation.")

# Generate enhanced features for both training and test sets
print("🚀 Generating enhanced molecular features...")
train_features_list = parallel_enhanced_feature_generation(train_df[SMILES_COL].tolist(), num_cores)
test_features_list = parallel_enhanced_feature_generation(test_df[SMILES_COL].tolist(), num_cores)

# Convert to DataFrames
train_enhanced_features = pd.DataFrame(train_features_list).fillna(0)
test_enhanced_features = pd.DataFrame(test_features_list).fillna(0)

print(f"✅ Generated {train_enhanced_features.shape[1]} enhanced features!")

# Ensure same columns in both datasets
common_features = list(set(train_enhanced_features.columns) & set(test_enhanced_features.columns))
train_enhanced_features = train_enhanced_features[common_features]
test_enhanced_features = test_enhanced_features[common_features]

# Remove constant features
constant_features = []
for col in train_enhanced_features.columns:
    if train_enhanced_features[col].nunique() <= 1:
        constant_features.append(col)

train_enhanced_features = train_enhanced_features.drop(columns=constant_features)
test_enhanced_features = test_enhanced_features.drop(columns=constant_features)

print(f"🗑️  Removed {len(constant_features)} constant features")

# Combine with existing features and target
train_ag = pd.concat([train_df.drop(columns=[SMILES_COL, ID_COL]), train_enhanced_features], axis=1)
test_ag = pd.concat([test_df.drop(columns=[SMILES_COL, ID_COL]), test_enhanced_features], axis=1)

print(f"✅ Final dataset shapes:")
print(f"Train: {train_ag.shape}")
print(f"Test: {test_ag.shape}")
print(f"🎯 Enhanced feature engineering completed with {train_ag.shape[1]} total features!")
# Out:
# Train data shape: (2662, 427)
# Test data shape: (666, 426)
# Using 4 CPU cores for enhanced feature generation.
# 🚀 Generating enhanced molecular features...
# Processing SMILES:   0%|          | 0/665 [00:00<?, ?it/s][18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   0%|          | 1/665 [00:00<01:31,  7.27it/s][18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   0%|          | 1/666 [00:00<01:34,  7.02it/s][18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   0%|          | 1/665 [00:00<01:43,  6.42it/s][18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   0%|          | 3/666 [00:00<00:55, 11.89it/s][18:49:30] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   0%|          | 3/666 [00:00<00:57, 11.51it/s][18:49:30] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   1%|          | 4/665 [00:00<00:42, 15.49it/s][18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   1%|          | 4/665 [00:00<00:43, 15.14it/s][18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   1%|          | 6/666 [00:00<00:40, 16.25it/s][18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   1%|          | 7/665 [00:00<00:38, 17.13it/s][18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   1%|          | 6/665 [00:00<00:54, 12.08it/s][18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   2%|▏         | 10/665 [00:00<00:31, 20.91it/s][18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:30] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   1%|▏         | 9/665 [00:00<00:38, 16.95it/s][18:49:30] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   2%|▏         | 11/666 [00:00<00:37, 17.43it/s][18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   2%|▏         | 11/665 [00:00<00:43, 14.90it/s][18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   2%|▏         | 13/665 [00:00<00:38, 16.89it/s][18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   2%|▏         | 13/665 [00:00<00:42, 15.40it/s][18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   2%|▏         | 16/665 [00:00<00:40, 16.02it/s][18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   2%|▏         | 13/666 [00:01<00:55, 11.78it/s][18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   2%|▏         | 16/665 [00:01<00:39, 16.46it/s][18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   1%|          | 8/666 [00:01<01:51,  5.88it/s][18:49:31] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   3%|▎         | 18/665 [00:01<00:41, 15.54it/s][18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   3%|▎         | 19/665 [00:01<00:34, 18.70it/s][18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   2%|▏         | 15/666 [00:01<01:00, 10.81it/s][18:49:31] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   2%|▏         | 11/666 [00:01<01:14,  8.78it/s][18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   3%|▎         | 21/665 [00:01<00:39, 16.12it/s][18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   3%|▎         | 21/665 [00:01<00:39, 16.31it/s][18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   3%|▎         | 17/666 [00:01<00:52, 12.43it/s][18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   2%|▏         | 13/666 [00:01<01:02, 10.45it/s][18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   3%|▎         | 23/665 [00:01<00:38, 16.59it/s][18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   2%|▏         | 16/666 [00:01<00:47, 13.56it/s][18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   3%|▎         | 23/665 [00:01<00:41, 15.31it/s][18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   4%|▍         | 25/665 [00:01<00:36, 17.31it/s][18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   3%|▎         | 18/666 [00:01<00:45, 14.20it/s][18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# [18:49:31] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   4%|▍         | 25/665 [00:01<00:41, 15.32it/s][18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   3%|▎         | 23/666 [00:01<00:39, 16.39it/s][18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   4%|▍         | 27/665 [00:01<00:39, 15.95it/s][18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   4%|▍         | 27/665 [00:01<00:40, 15.87it/s][18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   3%|▎         | 20/666 [00:01<00:50, 12.70it/s][18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   4%|▍         | 29/665 [00:01<00:43, 14.69it/s][18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   4%|▍         | 28/666 [00:01<00:35, 18.01it/s][18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   3%|▎         | 22/666 [00:01<00:48, 13.37it/s][18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   4%|▍         | 25/666 [00:02<00:40, 15.78it/s][18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   5%|▍         | 32/666 [00:02<00:32, 19.36it/s][18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   5%|▍         | 31/665 [00:02<01:01, 10.31it/s][18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   5%|▍         | 30/665 [00:02<01:01, 10.37it/s][18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   5%|▌         | 34/665 [00:02<00:49, 12.84it/s][18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   5%|▌         | 34/666 [00:02<00:41, 15.19it/s][18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   4%|▍         | 27/666 [00:02<00:53, 12.03it/s][18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   6%|▌         | 37/665 [00:02<00:41, 15.22it/s][18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   4%|▍         | 29/666 [00:02<00:49, 12.93it/s][18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   5%|▌         | 36/665 [00:02<00:44, 14.26it/s][18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   5%|▌         | 36/666 [00:02<00:47, 13.16it/s][18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   6%|▌         | 40/665 [00:02<00:36, 17.08it/s][18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:32] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   6%|▌         | 38/665 [00:02<00:42, 14.67it/s][18:49:32] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   6%|▌         | 38/666 [00:02<00:44, 14.01it/s][18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   6%|▋         | 43/665 [00:02<00:33, 18.74it/s][18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   6%|▌         | 41/665 [00:02<00:36, 16.92it/s][18:49:33] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   5%|▍         | 33/666 [00:02<00:48, 13.09it/s][18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   6%|▌         | 40/666 [00:02<00:43, 14.45it/s][18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   7%|▋         | 46/665 [00:02<00:29, 21.17it/s][18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   6%|▋         | 43/665 [00:02<00:36, 17.00it/s][18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   5%|▌         | 35/666 [00:02<00:45, 13.72it/s][18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   6%|▋         | 43/666 [00:02<00:38, 16.13it/s][18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   7%|▋         | 49/665 [00:02<00:29, 20.82it/s][18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   7%|▋         | 46/665 [00:03<00:34, 18.01it/s][18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   6%|▌         | 38/666 [00:03<00:44, 14.14it/s][18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   7%|▋         | 48/665 [00:03<00:35, 17.38it/s][18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   8%|▊         | 52/665 [00:03<00:36, 16.98it/s][18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   8%|▊         | 50/665 [00:03<00:35, 17.24it/s][18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   7%|▋         | 47/666 [00:03<00:45, 13.67it/s][18:49:33] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   8%|▊         | 55/665 [00:03<00:32, 18.99it/s][18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   6%|▋         | 43/666 [00:03<00:40, 15.26it/s][18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   7%|▋         | 49/666 [00:03<00:41, 14.75it/s][18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] UFFTYPER: Unrecognized charge state for atom: 1
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   9%|▊         | 58/665 [00:03<00:31, 19.45it/s][18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   8%|▊         | 51/666 [00:03<00:39, 15.60it/s][18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   8%|▊         | 52/665 [00:03<00:53, 11.51it/s][18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:33] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   8%|▊         | 53/666 [00:03<00:37, 16.34it/s][18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   8%|▊         | 54/665 [00:03<00:48, 12.70it/s][18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   8%|▊         | 56/666 [00:03<00:33, 17.97it/s][18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   8%|▊         | 56/665 [00:03<00:51, 11.74it/s][18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   9%|▊         | 58/666 [00:03<00:41, 14.61it/s][18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   9%|▉         | 61/666 [00:04<00:36, 16.60it/s][18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   9%|▉         | 61/665 [00:04<01:03,  9.50it/s][18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   7%|▋         | 47/666 [00:04<01:12,  8.52it/s][18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:   9%|▊         | 58/665 [00:04<01:05,  9.28it/s][18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  10%|▉         | 64/666 [00:04<00:32, 18.81it/s][18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# [18:49:34] DEPRECATION WARNING: please use MorganGenerator
# ...
# [18:50:31] DEPRECATION WARNING: please use MorganGenerator
# [18:50:31] DEPRECATION WARNING: please use MorganGenerator
# [18:50:31] DEPRECATION WARNING: please use MorganGenerator
# [18:50:31] DEPRECATION WARNING: please use MorganGenerator
# [18:50:31] DEPRECATION WARNING: please use MorganGenerator
# [18:50:31] DEPRECATION WARNING: please use MorganGenerator
# [18:50:31] DEPRECATION WARNING: please use MorganGenerator
# [18:50:31] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  90%|█████████ | 150/166 [00:10<00:01, 12.56it/s][18:50:31] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  93%|█████████▎| 154/166 [00:10<00:00, 16.47it/s][18:50:31] DEPRECATION WARNING: please use MorganGenerator
# [18:50:31] DEPRECATION WARNING: please use MorganGenerator
# [18:50:31] DEPRECATION WARNING: please use MorganGenerator
# [18:50:31] DEPRECATION WARNING: please use MorganGenerator
# [18:50:31] DEPRECATION WARNING: please use MorganGenerator
# [18:50:31] DEPRECATION WARNING: please use MorganGenerator
# [18:50:31] DEPRECATION WARNING: please use MorganGenerator
# [18:50:31] DEPRECATION WARNING: please use MorganGenerator
# [18:50:31] DEPRECATION WARNING: please use MorganGenerator
# [18:50:31] DEPRECATION WARNING: please use MorganGenerator
# [18:50:31] DEPRECATION WARNING: please use MorganGenerator
# [18:50:31] DEPRECATION WARNING: please use MorganGenerator
# [18:50:31] DEPRECATION WARNING: please use MorganGenerator
# [18:50:31] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  96%|█████████▌| 160/167 [00:10<00:00, 14.16it/s][18:50:31] DEPRECATION WARNING: please use MorganGenerator
# [18:50:31] DEPRECATION WARNING: please use MorganGenerator
# [18:50:31] DEPRECATION WARNING: please use MorganGenerator
# [18:50:31] DEPRECATION WARNING: please use MorganGenerator
# [18:50:31] DEPRECATION WARNING: please use MorganGenerator
# [18:50:31] DEPRECATION WARNING: please use MorganGenerator
# [18:50:31] DEPRECATION WARNING: please use MorganGenerator
# [18:50:31] DEPRECATION WARNING: please use MorganGenerator
# [18:50:31] DEPRECATION WARNING: please use MorganGenerator
# [18:50:31] DEPRECATION WARNING: please use MorganGenerator
# [18:50:31] DEPRECATION WARNING: please use MorganGenerator
# [18:50:31] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  92%|█████████▏| 152/166 [00:10<00:01, 13.57it/s][18:50:31] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  95%|█████████▍| 157/166 [00:10<00:00, 18.85it/s][18:50:31] DEPRECATION WARNING: please use MorganGenerator
# [18:50:31] DEPRECATION WARNING: please use MorganGenerator
# [18:50:31] DEPRECATION WARNING: please use MorganGenerator
# [18:50:31] DEPRECATION WARNING: please use MorganGenerator
# [18:50:31] DEPRECATION WARNING: please use MorganGenerator
# [18:50:31] DEPRECATION WARNING: please use MorganGenerator
# [18:50:31] DEPRECATION WARNING: please use MorganGenerator
# [18:50:31] DEPRECATION WARNING: please use MorganGenerator
# [18:50:31] DEPRECATION WARNING: please use MorganGenerator
# [18:50:31] DEPRECATION WARNING: please use MorganGenerator
# [18:50:31] DEPRECATION WARNING: please use MorganGenerator
# [18:50:31] DEPRECATION WARNING: please use MorganGenerator
# [18:50:31] DEPRECATION WARNING: please use MorganGenerator
# [18:50:31] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  98%|█████████▊| 163/167 [00:10<00:00, 15.48it/s][18:50:31] DEPRECATION WARNING: please use MorganGenerator
# [18:50:31] DEPRECATION WARNING: please use MorganGenerator
# [18:50:31] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  96%|█████████▋| 160/166 [00:10<00:00, 20.57it/s][18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  78%|███████▊  | 131/167 [00:10<00:03, 11.08it/s][18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  99%|█████████▉| 165/167 [00:10<00:00, 15.01it/s][18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  98%|█████████▊| 163/166 [00:10<00:00, 20.43it/s][18:50:32] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  93%|█████████▎| 154/166 [00:10<00:01, 10.73it/s][18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  80%|███████▉  | 133/167 [00:10<00:02, 11.96it/s][18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES: 100%|██████████| 167/167 [00:10<00:00, 15.34it/s]
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  95%|█████████▍| 157/166 [00:10<00:00, 13.46it/s][18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  81%|████████  | 135/167 [00:10<00:02, 12.57it/s][18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  96%|█████████▌| 159/166 [00:11<00:00, 12.26it/s][18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  82%|████████▏ | 137/167 [00:11<00:02, 11.42it/s][18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES: 100%|██████████| 166/166 [00:11<00:00, 14.78it/s][18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
#
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  97%|█████████▋| 161/166 [00:11<00:00, 13.34it/s][18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  84%|████████▍ | 140/167 [00:11<00:01, 13.84it/s][18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  98%|█████████▊| 163/166 [00:11<00:00, 12.81it/s][18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  85%|████████▌ | 142/167 [00:11<00:01, 13.59it/s][18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES: 100%|██████████| 166/166 [00:11<00:00, 14.41it/s]
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  87%|████████▋ | 145/167 [00:11<00:01, 16.66it/s][18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:32] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  88%|████████▊ | 147/167 [00:11<00:01, 17.12it/s][18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  90%|████████▉ | 150/167 [00:11<00:00, 19.16it/s][18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  93%|█████████▎| 155/167 [00:11<00:00, 26.70it/s][18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  95%|█████████▌| 159/167 [00:12<00:00, 28.15it/s][18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES:  98%|█████████▊| 164/167 [00:12<00:00, 31.15it/s][18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# [18:50:33] DEPRECATION WARNING: please use MorganGenerator
# Processing SMILES: 100%|██████████| 167/167 [00:12<00:00, 13.63it/s]
# ✅ Generated 1944 enhanced features!
# 🗑️  Removed 51 constant features
# ✅ Final dataset shapes:
# Train: (2662, 2318)
# Test: (666, 2317)
# 🎯 Enhanced feature engineering completed with 2318 total features!

# %% [markdown]
# <!-- ================= H2 HEADER: Execute Feature Generation ================= -->
# <div style="border-radius:25px 70px; padding:14px 18px; margin:10px 0;
#             font-family:'Quicksand', sans-serif; background:#24a695; overflow:hidden;">
#   <div style="text-align:center; color:#ffffff; font-size:150%; margin:0; padding:0;">
#     <b><h2 style="margin:0; color:#ffffff;">Execute Feature Generation</h2></b>
#   </div>
# </div>

# %%
print(f"Shape of training data after RDKit feature generation: {train_ag.shape}")
print(f"Shape of test data after RDKit feature generation: {test_ag.shape}")
print(f"Number of total features: {test_ag.shape[1]}")
# Out:
# Shape of training data after RDKit feature generation: (2662, 2318)
# Shape of test data after RDKit feature generation: (666, 2317)
# Number of total features: 2317

# %% [markdown]
# <!-- ================= H2 HEADER: AutoGluon Training and Prediction ================= -->
# <div style="border-radius:25px 70px; padding:14px 18px; margin:10px 0;
#             font-family:'Quicksand', sans-serif; background:#24a695; overflow:hidden;">
#   <div style="text-align:center; color:#ffffff; font-size:150%; margin:0; padding:0;">
#     <b><h2 style="margin:0; color:#ffffff;">AutoGluon Training and Prediction</h2></b>
#   </div>
# </div>
#
# <!-- ================= BADGES: AutoGluon Training Steps ================= -->
# <div style="display:flex; gap:10px; flex-wrap:wrap; justify-content:center; margin:12px 0; font-family:Inter, system-ui, 'Segoe UI', Roboto, Arial, sans-serif;">
#   <span style="background:#e2e8f0; color:#0f172a; padding:6px 14px; border-radius:999px; font-size:13px; border:1px solid #cbd5e1;">Initialize Predictor</span>
#   <span style="background:#dbeafe; color:#1e3a8a; padding:6px 14px; border-radius:999px; font-size:13px; border:1px solid #bfdbfe;">Set Label & Problem Type</span>
#   <span style="background:#dcfce7; color:#14532d; padding:6px 14px; border-radius:999px; font-size:13px; border:1px solid #bbf7d0;">Fit Model on Train Data</span>
#   <span style="background:#fde68a; color:#92400e; padding:6px 14px; border-radius:999px; font-size:13px; border:1px solid #fcd34d;">Set Time Limit & Presets</span>
# </div>

# %%
predictor = TabularPredictor(
    label=TARGET,
    problem_type='regression',
    eval_metric='mae'
).fit(
    train_data=train_ag,
    time_limit=3600*11,
    presets='best_quality' 
)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20250912_185042"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.4.0
# Python Version:     3.11.13
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP PREEMPT_DYNAMIC Sun Nov 10 10:07:59 UTC 2024
# CPU Count:          4
# Memory Avail:       29.46 GB / 31.35 GB (94.0%)
# Disk Space Avail:   19.50 GB / 19.52 GB (99.9%)
# ===================================================
# Presets specified: ['best_quality']
# Using hyperparameters preset: hyperparameters='zeroshot'
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 9900s of the 39600s of remaining time (25%).
# 		Context path: "/kaggle/working/AutogluonModels/ag-20250912_185042/ds_sub_fit/sub_fit_ho"
# Running DyStack sub-fit ...
# Beginning AutoGluon training ... Time limit = 9899s
# AutoGluon will save models to "/kaggle/working/AutogluonModels/ag-20250912_185042/ds_sub_fit/sub_fit_ho"
# Train Data Rows:    2366
# Train Data Columns: 2317
# Label Column:       Tm
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    30072.90 MB
# 	Train Data (Original)  Memory Usage: 41.82 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 1882 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Useless Original Features (Count: 93): ['Group 12', 'Group 28', 'Group 46', 'Group 67', 'Group 73', 'Group 74', 'Group 75', 'Group 84', 'Group 85', 'Group 88', 'Group 90', 'Group 93', 'Group 101', 'Group 102', 'Group 104', 'Group 107', 'Group 137', 'Group 150', 'Group 152', 'Group 155', 'Group 158', 'Group 160', 'Group 167', 'Group 183', 'Group 194', 'Group 198', 'Group 206', 'Group 207', 'Group 208', 'Group 209', 'Group 212', 'Group 213', 'Group 214', 'Group 215', 'Group 216', 'Group 217', 'Group 218', 'Group 245', 'Group 247', 'Group 248', 'Group 250', 'Group 252', 'Group 253', 'Group 256', 'Group 264', 'Group 280', 'Group 281', 'Group 282', 'Group 285', 'Group 294', 'Group 299', 'Group 303', 'Group 306', 'Group 307', 'Group 308', 'Group 309', 'Group 312', 'Group 313', 'Group 316', 'Group 317', 'Group 340', 'Group 342', 'Group 345', 'Group 347', 'Group 348', 'Group 349', 'Group 350', 'Group 352', 'Group 355', 'Group 356', 'Group 357', 'Group 358', 'Group 360', 'Group 363', 'Group 371', 'Group 376', 'Group 377', 'Group 383', 'Group 384', 'Group 385', 'Group 390', 'Group 397', 'Group 399', 'Group 410', 'Group 411', 'Group 413', 'Group 417', 'Group 419', 'Group 420', 'Group 421', 'Group 422', 'Group 423', 'Group 424']
# 		These features carry no predictive signal and should be manually investigated.
# 		This is typically a feature which has the same value for all rows.
# 		These features do not need to be present at inference time.
# 	Unused Original Features (Count: 44): ['Group 386', 'Morgan_R4_169', 'fr_nitroso', 'fr_COO', 'NumAtomStereoCenters', 'Morgan_R2_337', 'Morgan_R4_79', 'Morgan_R4_142', 'fr_azo', 'fr_isocyan', 'fr_phenol', 'FG_Carbonyl', 'Morgan_R4_289', 'fr_phos_acid', 'Morgan_R4_124', 'NumAmideBonds', 'Morgan_R3_175', 'Morgan_R4_282', 'FG_Ester', 'Morgan_R3_490', 'fr_ether', 'Morgan_R4_62', 'Morgan_R4_343', 'Morgan_R3_49', 'MACCS_13', 'Morgan_R3_360', 'FG_Carboxyl', 'fr_Nhpyrrole', 'MACCS_61', 'MaxEStateIndex', 'Morgan_R4_331', 'MACCS_143', 'fr_benzene', 'Morgan_R3_271', 'MACCS_39', 'Morgan_R3_221', 'Morgan_R4_287', 'NumAromaticCarbocycles', 'Morgan_R3_233', 'Morgan_R3_259', 'Morgan_R3_310', 'Morgan_R4_131', 'Morgan_R3_108', 'Morgan_R4_76']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('float', []) :  1 | ['MaxEStateIndex']
# 		('int', [])   : 43 | ['Group 386', 'Morgan_R4_169', 'fr_nitroso', 'fr_COO', 'NumAtomStereoCenters', ...]
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) :   97 | ['VSA_EState5', 'EState_VSA2', 'Chi2n', 'MolMR', 'Chi3n', ...]
# 		('int', [])   : 2083 | ['Group 1', 'Group 2', 'Group 3', 'Group 4', 'Group 5', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     :   97 | ['VSA_EState5', 'EState_VSA2', 'Chi2n', 'MolMR', 'Chi3n', ...]
# 		('int', [])       :  233 | ['Group 1', 'Group 2', 'Group 3', 'Group 4', 'Group 5', ...]
# 		('int', ['bool']) : 1850 | ['Group 10', 'Group 11', 'Group 14', 'Group 24', 'Group 26', ...]
# 	37.3s = Fit runtime
# 	2180 features in original data used to generate 2180 features in processed data.
# 	Train Data (Processed) Memory Usage: 10.13 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 37.67s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (110 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 106 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 6572.31s of the 9860.90s of remaining time.
# Will use sequential fold fitting strategy because import of ray failed. Reason: ray==2.47.1 detected. 2.10.0 <= ray < 2.45.0 is required. You can use pip to install certain version of ray `pip install "ray>=2.10.0,<2.45.0"`
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# [1000]	valid_set's l1: 28.8109
# [1000]	valid_set's l1: 27.5491
# [2000]	valid_set's l1: 27.2279
# [3000]	valid_set's l1: 27.1245
# 	-27.5376	 = Validation score   (-mean_absolute_error)
# 	81.52s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 6482.10s of the 9770.69s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-28.305	 = Validation score   (-mean_absolute_error)
# 	56.86s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 6423.82s of the 9712.42s of remaining time.
# 	-29.7334	 = Validation score   (-mean_absolute_error)
# 	111.84s	 = Training   runtime
# 	1.94s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 6309.38s of the 9597.97s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-27.1742	 = Validation score   (-mean_absolute_error)
# 	1407.55s	 = Training   runtime
# 	0.98s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 4899.63s of the 8188.22s of remaining time.
# 	-29.5579	 = Validation score   (-mean_absolute_error)
# 	93.08s	 = Training   runtime
# 	1.98s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 4803.83s of the 8092.42s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-30.0864	 = Validation score   (-mean_absolute_error)
# 	84.69s	 = Training   runtime
# 	0.32s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 4717.44s of the 8006.03s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-28.3468	 = Validation score   (-mean_absolute_error)
# 	404.11s	 = Training   runtime
# 	0.36s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 4311.68s of the 7600.28s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-29.762	 = Validation score   (-mean_absolute_error)
# 	242.27s	 = Training   runtime
# 	1.76s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 4066.53s of the 7355.12s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# [1000]	valid_set's l1: 23.8045
# [2000]	valid_set's l1: 23.8042
# [1000]	valid_set's l1: 30.0996
# [2000]	valid_set's l1: 30.0991
# [3000]	valid_set's l1: 30.0991
# [4000]	valid_set's l1: 30.0991
# [1000]	valid_set's l1: 26.5541
# [2000]	valid_set's l1: 26.5535
# [1000]	valid_set's l1: 31.7424
# [2000]	valid_set's l1: 31.7422
# [3000]	valid_set's l1: 31.7422
# [4000]	valid_set's l1: 31.7422
# [5000]	valid_set's l1: 31.7422
# [6000]	valid_set's l1: 31.7422
# [7000]	valid_set's l1: 31.7422
# [8000]	valid_set's l1: 31.7422
# 	-28.972	 = Validation score   (-mean_absolute_error)
# 	716.65s	 = Training   runtime
# 	1.5s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 3341.37s of the 6629.97s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	Ran out of time, early stopping on iteration 8889.
# 	Ran out of time, early stopping on iteration 8740.
# 	-27.5464	 = Validation score   (-mean_absolute_error)
# 	1225.8s	 = Training   runtime
# 	0.78s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 2113.60s of the 5402.20s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-33.1352	 = Validation score   (-mean_absolute_error)
# 	314.57s	 = Training   runtime
# 	2.07s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 1795.79s of the 5084.38s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# [1000]	valid_set's l1: 28.7278
# [1000]	valid_set's l1: 24.2141
# [1000]	valid_set's l1: 26.9532
# [1000]	valid_set's l1: 29.3761
# [1000]	valid_set's l1: 26.518
# [1000]	valid_set's l1: 29.5977
# [1000]	valid_set's l1: 27.3336
# [2000]	valid_set's l1: 27.2373
# 	-27.8726	 = Validation score   (-mean_absolute_error)
# 	154.19s	 = Training   runtime
# 	0.46s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 1638.72s of the 4927.31s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-30.3664	 = Validation score   (-mean_absolute_error)
# 	212.79s	 = Training   runtime
# 	0.4s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 1423.97s of the 4712.57s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	Ran out of time, early stopping on iteration 970.
# 	Ran out of time, early stopping on iteration 1006.
# 	Ran out of time, early stopping on iteration 1118.
# 	Ran out of time, early stopping on iteration 1173.
# 	Ran out of time, early stopping on iteration 1273.
# 	Ran out of time, early stopping on iteration 1369.
# 	Ran out of time, early stopping on iteration 1490.
# 	Ran out of time, early stopping on iteration 1882.
# 	-27.8935	 = Validation score   (-mean_absolute_error)
# 	1363.88s	 = Training   runtime
# 	1.28s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 57.65s of the 3346.24s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	Ran out of time, early stopping on iteration 992. Best iteration is:
# 	[992]	valid_set's l1: 29.2868
# 	Ran out of time, early stopping on iteration 922. Best iteration is:
# 	[919]	valid_set's l1: 25.136
# [1000]	valid_set's l1: 28.2324
# 	Ran out of time, early stopping on iteration 1083. Best iteration is:
# 	[1079]	valid_set's l1: 28.0479
# 	Ran out of time, early stopping on iteration 1038. Best iteration is:
# 	[1034]	valid_set's l1: 30.1576
# [1000]	valid_set's l1: 30.2056
# 	Ran out of time, early stopping on iteration 1041. Best iteration is:
# 	[1041]	valid_set's l1: 28.3682
# [1000]	valid_set's l1: 28.4589
# 	Ran out of time, early stopping on iteration 973. Best iteration is:
# 	[973]	valid_set's l1: 30.4754
# [1000]	valid_set's l1: 28.1186
# 	Ran out of time, early stopping on iteration 1094. Best iteration is:
# 	[1087]	valid_set's l1: 27.9497
# [1000]	valid_set's l1: 31.8777
# 	Ran out of time, early stopping on iteration 1732. Best iteration is:
# 	[1732]	valid_set's l1: 31.2675
# 	-28.8355	 = Validation score   (-mean_absolute_error)
# 	53.83s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 1.87s of the 3290.46s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	Warning: Model has no time left to train, skipping model... (Time Left = -0.5s)
# 	Time limit exceeded... Skipping NeuralNetTorch_r22_BAG_L1.
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 657.23s of the 3288.25s of remaining time.
# 	Ensemble Weights: {'LightGBMXT_BAG_L1': 0.28, 'CatBoost_BAG_L1': 0.24, 'CatBoost_r177_BAG_L1': 0.12, 'NeuralNetTorch_r79_BAG_L1': 0.12, 'NeuralNetFastAI_BAG_L1': 0.08, 'LightGBM_r131_BAG_L1': 0.08, 'XGBoost_BAG_L1': 0.04, 'NeuralNetFastAI_r191_BAG_L1': 0.04}
# 	-26.1034	 = Validation score   (-mean_absolute_error)
# 	0.12s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 106 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 3288.10s of the 3288.05s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-27.7476	 = Validation score   (-mean_absolute_error)
# 	33.71s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 3253.19s of the 3253.14s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-27.8262	 = Validation score   (-mean_absolute_error)
# 	45.26s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ... Training model for up to 3206.69s of the 3206.64s of remaining time.
# 	-27.1805	 = Validation score   (-mean_absolute_error)
# 	134.69s	 = Training   runtime
# 	1.92s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 3069.31s of the 3069.26s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-26.7244	 = Validation score   (-mean_absolute_error)
# 	135.74s	 = Training   runtime
# 	1.04s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ... Training model for up to 2931.43s of the 2931.38s of remaining time.
# 	-26.9043	 = Validation score   (-mean_absolute_error)
# 	99.8s	 = Training   runtime
# 	1.96s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 2828.98s of the 2828.93s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-31.0932	 = Validation score   (-mean_absolute_error)
# 	79.62s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 2747.68s of the 2747.63s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-28.0012	 = Validation score   (-mean_absolute_error)
# 	89.1s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 2657.31s of the 2657.26s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-28.5018	 = Validation score   (-mean_absolute_error)
# 	98.1s	 = Training   runtime
# 	1.64s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 2556.43s of the 2556.38s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-28.2647	 = Validation score   (-mean_absolute_error)
# 	159.69s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L2 ... Training model for up to 2395.17s of the 2395.12s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-26.8259	 = Validation score   (-mean_absolute_error)
# 	115.89s	 = Training   runtime
# 	0.71s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L2 ... Training model for up to 2277.54s of the 2277.49s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-33.5395	 = Validation score   (-mean_absolute_error)
# 	164.04s	 = Training   runtime
# 	1.64s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L2 ... Training model for up to 2110.69s of the 2110.65s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-27.7541	 = Validation score   (-mean_absolute_error)
# 	72.1s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L2 ... Training model for up to 2037.11s of the 2037.06s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-30.9497	 = Validation score   (-mean_absolute_error)
# 	195.7s	 = Training   runtime
# 	0.41s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L2 ... Training model for up to 1839.51s of the 1839.46s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-26.842	 = Validation score   (-mean_absolute_error)
# 	617.22s	 = Training   runtime
# 	1.09s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L2 ... Training model for up to 1220.09s of the 1220.04s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-27.4809	 = Validation score   (-mean_absolute_error)
# 	29.94s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L2 ... Training model for up to 1188.87s of the 1188.82s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-27.7162	 = Validation score   (-mean_absolute_error)
# 	122.2s	 = Training   runtime
# 	1.68s	 = Validation runtime
# Fitting model: XGBoost_r33_BAG_L2 ... Training model for up to 1063.84s of the 1063.79s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-28.0459	 = Validation score   (-mean_absolute_error)
# 	290.92s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: ExtraTrees_r42_BAG_L2 ... Training model for up to 771.50s of the 771.46s of remaining time.
# 	-27.0758	 = Validation score   (-mean_absolute_error)
# 	72.33s	 = Training   runtime
# 	1.87s	 = Validation runtime
# Fitting model: CatBoost_r137_BAG_L2 ... Training model for up to 696.65s of the 696.60s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-26.4907	 = Validation score   (-mean_absolute_error)
# 	65.91s	 = Training   runtime
# 	1.02s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r102_BAG_L2 ... Training model for up to 628.70s of the 628.66s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# No improvement since epoch 0: early stopping
# No improvement since epoch 0: early stopping
# No improvement since epoch 0: early stopping
# No improvement since epoch 0: early stopping
# 	-42.5912	 = Validation score   (-mean_absolute_error)
# 	53.4s	 = Training   runtime
# 	0.38s	 = Validation runtime
# Fitting model: CatBoost_r13_BAG_L2 ... Training model for up to 573.15s of the 573.10s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	Ran out of time, early stopping on iteration 658.
# 	Ran out of time, early stopping on iteration 639.
# 	Ran out of time, early stopping on iteration 674.
# 	Ran out of time, early stopping on iteration 654.
# 	Ran out of time, early stopping on iteration 736.
# 	Ran out of time, early stopping on iteration 796.
# 	-26.6559	 = Validation score   (-mean_absolute_error)
# 	534.08s	 = Training   runtime
# 	1.19s	 = Validation runtime
# Fitting model: RandomForest_r195_BAG_L2 ... Training model for up to 36.76s of the 36.71s of remaining time.
# 	-27.2661	 = Validation score   (-mean_absolute_error)
# 	94.94s	 = Training   runtime
# 	1.91s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.00s of the -61.10s of remaining time.
# 	Ensemble Weights: {'CatBoost_r137_BAG_L2': 0.455, 'LightGBMXT_BAG_L1': 0.227, 'NeuralNetTorch_r22_BAG_L2': 0.136, 'ExtraTreesMSE_BAG_L2': 0.091, 'NeuralNetFastAI_BAG_L1': 0.045, 'NeuralNetFastAI_r191_BAG_L1': 0.045}
# 	-26.1948	 = Validation score   (-mean_absolute_error)
# 	0.15s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 9959.91s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 52.1 rows/s (296 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/kaggle/working/AutogluonModels/ag-20250912_185042/ds_sub_fit/sub_fit_ho")
# Deleting DyStack predictor artifacts (clean_up_fits=True) ...
# Leaderboard on holdout data (DyStack):
#                           model  score_holdout  score_val          eval_metric  pred_time_test  pred_time_val     fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0           CatBoost_r13_BAG_L2     -26.192933 -26.655918  mean_absolute_error       13.860622      12.560313  4866.505804                 1.079661                1.194416         534.084272            2       True         37
# 1           WeightedEnsemble_L3     -26.276708 -26.194816  mean_absolute_error       15.756023      16.023117  4620.484270                 0.004199                0.000924           0.148205            3       True         39
# 2           WeightedEnsemble_L2     -26.451312 -26.103372  mean_absolute_error        9.444846       5.679170  3885.343069                 0.006174                0.000879           0.123778            2       True         16
# 3          CatBoost_r137_BAG_L2     -26.457273 -26.490678  mean_absolute_error       13.840136      12.381881  4398.327927                 1.059175                1.015984          65.906396            2       True         35
# 4               CatBoost_BAG_L2     -26.467411 -26.724396  mean_absolute_error       13.839008      12.404750  4468.159967                 1.058047                1.038853         135.738436            2       True         20
# 5          CatBoost_r177_BAG_L2     -26.489398 -26.825891  mean_absolute_error       13.831150      12.074460  4448.312136                 1.050189                0.708562         115.890605            2       True         26
# 6        RandomForestMSE_BAG_L2     -26.517021 -27.180549  mean_absolute_error       12.940202      13.290207  4467.112541                 0.159241                1.924310         134.691010            2       True         19
# 7            CatBoost_r9_BAG_L2     -26.555635 -26.842042  mean_absolute_error       13.993599      12.459647  4949.641619                 1.212638                1.093750         617.220088            2       True         30
# 8         ExtraTrees_r42_BAG_L2     -26.626613 -27.075828  mean_absolute_error       13.033525      13.235391  4404.752863                 0.252564                1.869493          72.331331            2       True         34
# 9          ExtraTreesMSE_BAG_L2     -26.659490 -26.904319  mean_absolute_error       12.958732      13.330524  4432.224992                 0.177771                1.964627          99.803460            2       True         21
# 10     RandomForest_r195_BAG_L2     -26.664868 -27.266111  mean_absolute_error       12.944788      13.276954  4427.359756                 0.163826                1.911057          94.938225            2       True         38
# 11            LightGBMXT_BAG_L2     -26.844424 -27.747593  mean_absolute_error       12.915260      11.497551  4366.126726                 0.134299                0.131654          33.705195            2       True         17
# 12         LightGBM_r131_BAG_L2     -27.061712 -27.754135  mean_absolute_error       13.029479      11.526092  4404.518524                 0.248518                0.160195          72.096992            2       True         28
# 13         LightGBMLarge_BAG_L2     -27.105783 -28.264697  mean_absolute_error       13.007362      11.518780  4492.114452                 0.226401                0.152883         159.692921            2       True         25
# 14           XGBoost_r33_BAG_L2     -27.139625 -28.045896  mean_absolute_error       13.248520      11.619991  4623.340640                 0.467559                0.254094         290.919109            2       True         33
# 15          LightGBM_r96_BAG_L2     -27.191736 -27.480851  mean_absolute_error       12.979147      11.523632  4362.360454                 0.198186                0.157735          29.938922            2       True         31
# 16               XGBoost_BAG_L2     -27.289041 -28.001237  mean_absolute_error       13.073380      11.550398  4421.517301                 0.292419                0.184501          89.095769            2       True         23
# 17              CatBoost_BAG_L1     -27.358957 -27.174234  mean_absolute_error        1.639920       0.984599  1407.552789                 1.639920                0.984599        1407.552789            1       True          4
# 18              LightGBM_BAG_L2     -27.380807 -27.826191  mean_absolute_error       12.910840      11.497726  4377.678889                 0.129879                0.131829          45.257357            2       True         18
# 19    NeuralNetTorch_r22_BAG_L2     -27.392234 -27.716154  mean_absolute_error       14.514879      13.041583  4454.626209                 1.733918                1.675685         122.204677            2       True         32
# 20         CatBoost_r177_BAG_L1     -27.440408 -27.546408  mean_absolute_error        1.730484       0.780258  1225.804003                 1.730484                0.780258        1225.804003            1       True         10
# 21            LightGBMXT_BAG_L1     -27.581560 -27.537561  mean_absolute_error        0.704721       0.301818    81.519816                 0.704721                0.301818          81.519816            1       True          1
# 22  NeuralNetFastAI_r191_BAG_L2     -27.759620 -30.949708  mean_absolute_error       13.291083      11.775186  4528.120470                 0.510122                0.409288         195.698939            2       True         29
# 23               XGBoost_BAG_L1     -27.994484 -28.346836  mean_absolute_error        1.049014       0.358877   404.110017                 1.049014                0.358877         404.110017            1       True          7
# 24  NeuralNetFastAI_r191_BAG_L1     -28.064612 -30.366383  mean_absolute_error        0.856699       0.395291   212.786223                 0.856699                0.395291         212.786223            1       True         13
# 25       NeuralNetFastAI_BAG_L2     -28.111798 -31.093217  mean_absolute_error       13.151501      11.671970  4412.036813                 0.370540                0.306073          79.615282            2       True         22
# 26       NeuralNetFastAI_BAG_L1     -28.228710 -30.086381  mean_absolute_error        0.531518       0.320418    84.693579                 0.531518                0.320418          84.693579            1       True          6
# 27           CatBoost_r9_BAG_L1     -28.517905 -27.893549  mean_absolute_error        1.333148       1.282852  1363.876985                 1.333148                1.282852        1363.876985            1       True         14
# 28         LightGBM_r131_BAG_L1     -28.614160 -27.872606  mean_absolute_error        1.074295       0.464653   154.185882                 1.074295                0.464653         154.185882            1       True         12
# 29        NeuralNetTorch_BAG_L2     -28.842880 -28.501804  mean_absolute_error       14.432477      13.008730  4430.526086                 1.651516                1.642833          98.104555            2       True         24
# 30    NeuralNetTorch_r79_BAG_L2     -29.130445 -33.539506  mean_absolute_error       14.514595      13.008596  4496.465309                 1.733634                1.642699         164.043778            2       True         27
# 31              LightGBM_BAG_L1     -29.154182 -28.305017  mean_absolute_error        0.344182       0.172552    56.856457                 0.344182                0.172552          56.856457            1       True          2
# 32          LightGBM_r96_BAG_L1     -29.261281 -28.835484  mean_absolute_error        0.408649       0.303302    53.834146                 0.408649                0.303302          53.834146            1       True         15
# 33         LightGBMLarge_BAG_L1     -29.482809 -28.971969  mean_absolute_error        4.749352       1.496461   716.647311                 4.749352                1.496461         716.647311            1       True          9
# 34        NeuralNetTorch_BAG_L1     -29.597764 -29.762027  mean_absolute_error        1.865344       1.763123   242.273910                 1.865344                1.763123         242.273910            1       True          8
# 35         ExtraTreesMSE_BAG_L1     -29.704702 -29.557869  mean_absolute_error        0.642244       1.983587    93.083356                 0.642244                1.983587          93.083356            1       True          5
# 36    NeuralNetTorch_r79_BAG_L1     -30.144691 -33.135222  mean_absolute_error        1.852021       2.072378   314.566983                 1.852021                2.072378         314.566983            1       True         11
# 37       RandomForestMSE_BAG_L1     -31.501678 -29.733392  mean_absolute_error        0.834702       1.940895   111.844974                 0.834702                1.940895         111.844974            1       True          3
# 38  NeuralNetFastAI_r102_BAG_L2     -37.492526 -42.591211  mean_absolute_error       13.072651      11.744777  4385.820060                 0.291690                0.378880          53.398528            2       True         36
# 	1	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: False)
# 	9998s	 = DyStack   runtime |	29602s	 = Remaining runtime
# Starting main fit with num_stack_levels=1.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=1)`
# Beginning AutoGluon training ... Time limit = 29602s
# AutoGluon will save models to "/kaggle/working/AutogluonModels/ag-20250912_185042"
# Train Data Rows:    2662
# Train Data Columns: 2317
# Label Column:       Tm
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    28965.89 MB
# 	Train Data (Original)  Memory Usage: 47.06 MB (0.2% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 1885 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Useless Original Features (Count: 87): ['Group 12', 'Group 28', 'Group 46', 'Group 67', 'Group 73', 'Group 74', 'Group 75', 'Group 84', 'Group 85', 'Group 88', 'Group 90', 'Group 101', 'Group 102', 'Group 104', 'Group 150', 'Group 152', 'Group 155', 'Group 158', 'Group 160', 'Group 167', 'Group 183', 'Group 194', 'Group 198', 'Group 206', 'Group 207', 'Group 208', 'Group 209', 'Group 212', 'Group 213', 'Group 214', 'Group 215', 'Group 216', 'Group 217', 'Group 218', 'Group 245', 'Group 247', 'Group 248', 'Group 250', 'Group 252', 'Group 253', 'Group 264', 'Group 280', 'Group 281', 'Group 282', 'Group 285', 'Group 294', 'Group 303', 'Group 306', 'Group 307', 'Group 308', 'Group 309', 'Group 312', 'Group 313', 'Group 316', 'Group 317', 'Group 340', 'Group 342', 'Group 345', 'Group 347', 'Group 348', 'Group 349', 'Group 350', 'Group 352', 'Group 355', 'Group 356', 'Group 357', 'Group 358', 'Group 360', 'Group 363', 'Group 371', 'Group 376', 'Group 377', 'Group 383', 'Group 384', 'Group 385', 'Group 390', 'Group 397', 'Group 399', 'Group 411', 'Group 413', 'Group 417', 'Group 419', 'Group 420', 'Group 421', 'Group 422', 'Group 423', 'Group 424']
# 		These features carry no predictive signal and should be manually investigated.
# 		This is typically a feature which has the same value for all rows.
# 		These features do not need to be present at inference time.
# 	Unused Original Features (Count: 37): ['Group 386', 'fr_nitroso', 'fr_COO', 'NumAtomStereoCenters', 'Morgan_R2_337', 'Morgan_R4_79', 'Morgan_R4_142', 'fr_azo', 'fr_isocyan', 'FG_Carbonyl', 'Morgan_R4_289', 'fr_phos_acid', 'Morgan_R4_124', 'NumAmideBonds', 'Morgan_R3_175', 'Morgan_R4_282', 'FG_Ester', 'Morgan_R3_490', 'fr_ether', 'Morgan_R3_49', 'MACCS_13', 'FG_Carboxyl', 'fr_Nhpyrrole', 'MACCS_61', 'MaxEStateIndex', 'Morgan_R4_331', 'MACCS_143', 'fr_benzene', 'Morgan_R3_271', 'MACCS_39', 'Morgan_R3_221', 'NumAromaticCarbocycles', 'Morgan_R3_233', 'Morgan_R3_259', 'Morgan_R3_310', 'Morgan_R4_131', 'Morgan_R4_76']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('float', []) :  1 | ['MaxEStateIndex']
# 		('int', [])   : 36 | ['Group 386', 'fr_nitroso', 'fr_COO', 'NumAtomStereoCenters', 'Morgan_R2_337', ...]
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) :   97 | ['VSA_EState5', 'EState_VSA2', 'Chi2n', 'MolMR', 'Chi3n', ...]
# 		('int', [])   : 2096 | ['Group 1', 'Group 2', 'Group 3', 'Group 4', 'Group 5', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     :   97 | ['VSA_EState5', 'EState_VSA2', 'Chi2n', 'MolMR', 'Chi3n', ...]
# 		('int', [])       :  237 | ['Group 1', 'Group 2', 'Group 3', 'Group 4', 'Group 5', ...]
# 		('int', ['bool']) : 1859 | ['Group 10', 'Group 11', 'Group 14', 'Group 24', 'Group 26', ...]
# 	42.1s = Fit runtime
# 	2193 features in original data used to generate 2193 features in processed data.
# 	Train Data (Processed) Memory Usage: 11.50 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 42.51s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (110 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 106 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 19701.63s of the 29559.82s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# [1000]	valid_set's l1: 27.3366
# [1000]	valid_set's l1: 24.1236
# [1000]	valid_set's l1: 28.4314
# [2000]	valid_set's l1: 28.1013
# [3000]	valid_set's l1: 28.003
# [4000]	valid_set's l1: 27.9872
# [5000]	valid_set's l1: 27.9783
# [6000]	valid_set's l1: 27.9726
# [7000]	valid_set's l1: 27.9691
# [8000]	valid_set's l1: 27.9704
# [9000]	valid_set's l1: 27.97
# [1000]	valid_set's l1: 25.5499
# [2000]	valid_set's l1: 25.3935
# [1000]	valid_set's l1: 28.0397
# 	-26.7983	 = Validation score   (-mean_absolute_error)
# 	138.69s	 = Training   runtime
# 	0.73s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 19560.00s of the 29418.19s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# [1000]	valid_set's l1: 25.9031
# 	-27.7467	 = Validation score   (-mean_absolute_error)
# 	68.2s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 19490.16s of the 29348.35s of remaining time.
# 	-29.8271	 = Validation score   (-mean_absolute_error)
# 	127.68s	 = Training   runtime
# 	2.48s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 19359.34s of the 29217.53s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-26.7763	 = Validation score   (-mean_absolute_error)
# 	1813.8s	 = Training   runtime
# 	1.16s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 17543.19s of the 27401.38s of remaining time.
# 	-29.1244	 = Validation score   (-mean_absolute_error)
# 	97.34s	 = Training   runtime
# 	2.43s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 17442.68s of the 27300.87s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-30.0286	 = Validation score   (-mean_absolute_error)
# 	82.28s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 17358.71s of the 27216.90s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-27.7918	 = Validation score   (-mean_absolute_error)
# 	554.4s	 = Training   runtime
# 	0.49s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 16802.44s of the 26660.63s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-29.4997	 = Validation score   (-mean_absolute_error)
# 	256.55s	 = Training   runtime
# 	1.59s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 16543.17s of the 26401.36s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# [1000]	valid_set's l1: 31.4456
# [1000]	valid_set's l1: 26.5658
# [1000]	valid_set's l1: 29.1927
# [1000]	valid_set's l1: 26.6216
# [2000]	valid_set's l1: 26.6183
# [3000]	valid_set's l1: 26.6182
# [4000]	valid_set's l1: 26.6182
# [5000]	valid_set's l1: 26.6182
# [6000]	valid_set's l1: 26.6182
# [7000]	valid_set's l1: 26.6182
# [8000]	valid_set's l1: 26.6182
# [9000]	valid_set's l1: 26.6182
# [10000]	valid_set's l1: 26.6182
# 	-28.1203	 = Validation score   (-mean_absolute_error)
# 	623.57s	 = Training   runtime
# 	1.38s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 15912.29s of the 25770.48s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-26.9393	 = Validation score   (-mean_absolute_error)
# 	1473.15s	 = Training   runtime
# 	0.75s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 14437.22s of the 24295.41s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-32.3253	 = Validation score   (-mean_absolute_error)
# 	299.27s	 = Training   runtime
# 	1.62s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 14135.19s of the 23993.38s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# [1000]	valid_set's l1: 30.4255
# [1000]	valid_set's l1: 25.8717
# [2000]	valid_set's l1: 25.7446
# [3000]	valid_set's l1: 25.7337
# [1000]	valid_set's l1: 27.3948
# [1000]	valid_set's l1: 26.2621
# [2000]	valid_set's l1: 26.1841
# [1000]	valid_set's l1: 25.5226
# [2000]	valid_set's l1: 25.3661
# [1000]	valid_set's l1: 28.6913
# [1000]	valid_set's l1: 25.6469
# [2000]	valid_set's l1: 25.5154
# [3000]	valid_set's l1: 25.478
# ...
# 	-26.7882	 = Validation score   (-mean_absolute_error)
# 	28.34s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: NeuralNetTorch_r86_BAG_L2 ... Training model for up to 5777.83s of the 5777.76s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-27.9008	 = Validation score   (-mean_absolute_error)
# 	128.2s	 = Training   runtime
# 	1.71s	 = Validation runtime
# Fitting model: CatBoost_r50_BAG_L2 ... Training model for up to 5646.76s of the 5646.70s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-25.8524	 = Validation score   (-mean_absolute_error)
# 	96.51s	 = Training   runtime
# 	1.09s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r11_BAG_L2 ... Training model for up to 5548.08s of the 5548.02s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-33.6473	 = Validation score   (-mean_absolute_error)
# 	205.22s	 = Training   runtime
# 	0.45s	 = Validation runtime
# Fitting model: XGBoost_r194_BAG_L2 ... Training model for up to 5340.91s of the 5340.84s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-26.5306	 = Validation score   (-mean_absolute_error)
# 	129.45s	 = Training   runtime
# 	1.53s	 = Validation runtime
# Fitting model: ExtraTrees_r172_BAG_L2 ... Training model for up to 5208.73s of the 5208.67s of remaining time.
# 	-26.0361	 = Validation score   (-mean_absolute_error)
# 	47.88s	 = Training   runtime
# 	2.4s	 = Validation runtime
# Fitting model: CatBoost_r69_BAG_L2 ... Training model for up to 5157.82s of the 5157.76s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-25.864	 = Validation score   (-mean_absolute_error)
# 	96.43s	 = Training   runtime
# 	1.07s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r103_BAG_L2 ... Training model for up to 5059.26s of the 5059.19s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# No improvement since epoch 15: early stopping
# 	-30.014	 = Validation score   (-mean_absolute_error)
# 	146.37s	 = Training   runtime
# 	0.34s	 = Validation runtime
# Fitting model: NeuralNetTorch_r14_BAG_L2 ... Training model for up to 4911.05s of the 4910.98s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-34.1501	 = Validation score   (-mean_absolute_error)
# 	226.12s	 = Training   runtime
# 	1.72s	 = Validation runtime
# Fitting model: LightGBM_r161_BAG_L2 ... Training model for up to 4682.05s of the 4681.99s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# [1000]	valid_set's l1: 28.5647
# 	-26.7744	 = Validation score   (-mean_absolute_error)
# 	215.94s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r143_BAG_L2 ... Training model for up to 4463.17s of the 4463.11s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-29.0423	 = Validation score   (-mean_absolute_error)
# 	62.78s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: CatBoost_r70_BAG_L2 ... Training model for up to 4398.70s of the 4398.64s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-25.9261	 = Validation score   (-mean_absolute_error)
# 	260.48s	 = Training   runtime
# 	1.14s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r156_BAG_L2 ... Training model for up to 4135.99s of the 4135.93s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# No improvement since epoch 15: early stopping
# 	-31.8714	 = Validation score   (-mean_absolute_error)
# 	84.38s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: LightGBM_r196_BAG_L2 ... Training model for up to 4049.91s of the 4049.85s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# [1000]	valid_set's l1: 28.3574
# [1000]	valid_set's l1: 27.8451
# [2000]	valid_set's l1: 27.7923
# [1000]	valid_set's l1: 29.2923
# [1000]	valid_set's l1: 26.9962
# 	-27.2588	 = Validation score   (-mean_absolute_error)
# 	203.79s	 = Training   runtime
# 	0.46s	 = Validation runtime
# Fitting model: RandomForest_r39_BAG_L2 ... Training model for up to 3842.36s of the 3842.30s of remaining time.
# 	-26.1772	 = Validation score   (-mean_absolute_error)
# 	77.22s	 = Training   runtime
# 	2.43s	 = Validation runtime
# Fitting model: CatBoost_r167_BAG_L2 ... Training model for up to 3762.04s of the 3761.98s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-25.8985	 = Validation score   (-mean_absolute_error)
# 	187.98s	 = Training   runtime
# 	0.71s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r95_BAG_L2 ... Training model for up to 3572.24s of the 3572.18s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# No improvement since epoch 10: early stopping
# No improvement since epoch 11: early stopping
# No improvement since epoch 2: early stopping
# 	-31.8962	 = Validation score   (-mean_absolute_error)
# 	144.53s	 = Training   runtime
# 	0.4s	 = Validation runtime
# Fitting model: NeuralNetTorch_r41_BAG_L2 ... Training model for up to 3425.85s of the 3425.79s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-32.4342	 = Validation score   (-mean_absolute_error)
# 	90.07s	 = Training   runtime
# 	1.63s	 = Validation runtime
# Fitting model: XGBoost_r98_BAG_L2 ... Training model for up to 3332.99s of the 3332.93s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-26.416	 = Validation score   (-mean_absolute_error)
# 	400.59s	 = Training   runtime
# 	1.56s	 = Validation runtime
# Fitting model: LightGBM_r15_BAG_L2 ... Training model for up to 2929.57s of the 2929.51s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-26.2992	 = Validation score   (-mean_absolute_error)
# 	38.7s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: NeuralNetTorch_r158_BAG_L2 ... Training model for up to 2889.56s of the 2889.50s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-32.7731	 = Validation score   (-mean_absolute_error)
# 	153.73s	 = Training   runtime
# 	1.73s	 = Validation runtime
# Fitting model: CatBoost_r86_BAG_L2 ... Training model for up to 2732.82s of the 2732.76s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-25.8647	 = Validation score   (-mean_absolute_error)
# 	447.3s	 = Training   runtime
# 	1.14s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r37_BAG_L2 ... Training model for up to 2283.20s of the 2283.14s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# No improvement since epoch 13: early stopping
# 	-30.178	 = Validation score   (-mean_absolute_error)
# 	100.05s	 = Training   runtime
# 	0.29s	 = Validation runtime
# Fitting model: NeuralNetTorch_r197_BAG_L2 ... Training model for up to 2181.42s of the 2181.35s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-226.0482	 = Validation score   (-mean_absolute_error)
# 	84.32s	 = Training   runtime
# 	1.63s	 = Validation runtime
# Fitting model: CatBoost_r49_BAG_L2 ... Training model for up to 2094.31s of the 2094.25s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-25.8756	 = Validation score   (-mean_absolute_error)
# 	72.38s	 = Training   runtime
# 	0.73s	 = Validation runtime
# Fitting model: ExtraTrees_r49_BAG_L2 ... Training model for up to 2020.13s of the 2020.07s of remaining time.
# 	-27.0611	 = Validation score   (-mean_absolute_error)
# 	4.1s	 = Training   runtime
# 	2.59s	 = Validation runtime
# Fitting model: LightGBM_r143_BAG_L2 ... Training model for up to 2012.64s of the 2012.58s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-26.8818	 = Validation score   (-mean_absolute_error)
# 	112.77s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: RandomForest_r127_BAG_L2 ... Training model for up to 1898.05s of the 1897.98s of remaining time.
# 	-26.0664	 = Validation score   (-mean_absolute_error)
# 	64.41s	 = Training   runtime
# 	2.44s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r134_BAG_L2 ... Training model for up to 1830.56s of the 1830.50s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# No improvement since epoch 7: early stopping
# 	-32.147	 = Validation score   (-mean_absolute_error)
# 	154.16s	 = Training   runtime
# 	0.38s	 = Validation runtime
# Fitting model: RandomForest_r34_BAG_L2 ... Training model for up to 1674.45s of the 1674.38s of remaining time.
# 	-26.1311	 = Validation score   (-mean_absolute_error)
# 	20.43s	 = Training   runtime
# 	2.43s	 = Validation runtime
# Fitting model: LightGBM_r94_BAG_L2 ... Training model for up to 1650.97s of the 1650.91s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-26.6864	 = Validation score   (-mean_absolute_error)
# 	26.75s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: NeuralNetTorch_r143_BAG_L2 ... Training model for up to 1623.03s of the 1622.97s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-32.749	 = Validation score   (-mean_absolute_error)
# 	174.72s	 = Training   runtime
# 	1.69s	 = Validation runtime
# Fitting model: CatBoost_r128_BAG_L2 ... Training model for up to 1445.38s of the 1445.32s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-25.9622	 = Validation score   (-mean_absolute_error)
# 	578.32s	 = Training   runtime
# 	1.17s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r111_BAG_L2 ... Training model for up to 864.78s of the 864.72s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# No improvement since epoch 0: early stopping
# 	-49.129	 = Validation score   (-mean_absolute_error)
# 	49.31s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: NeuralNetTorch_r31_BAG_L2 ... Training model for up to 813.75s of the 813.69s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-76.7413	 = Validation score   (-mean_absolute_error)
# 	92.61s	 = Training   runtime
# 	1.73s	 = Validation runtime
# Fitting model: ExtraTrees_r4_BAG_L2 ... Training model for up to 718.24s of the 718.18s of remaining time.
# 	-25.9835	 = Validation score   (-mean_absolute_error)
# 	21.75s	 = Training   runtime
# 	2.33s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r65_BAG_L2 ... Training model for up to 693.55s of the 693.49s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# No improvement since epoch 9: early stopping
# 	-34.7662	 = Validation score   (-mean_absolute_error)
# 	78.91s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r88_BAG_L2 ... Training model for up to 612.93s of the 612.87s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# No improvement since epoch 24: early stopping
# No improvement since epoch 18: early stopping
# 	-31.429	 = Validation score   (-mean_absolute_error)
# 	95.5s	 = Training   runtime
# 	0.29s	 = Validation runtime
# Fitting model: LightGBM_r30_BAG_L2 ... Training model for up to 515.68s of the 515.61s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# [1000]	valid_set's l1: 28.9166
# 	-26.8396	 = Validation score   (-mean_absolute_error)
# 	75.35s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: XGBoost_r49_BAG_L2 ... Training model for up to 438.43s of the 438.37s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-26.5788	 = Validation score   (-mean_absolute_error)
# 	122.58s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: CatBoost_r5_BAG_L2 ... Training model for up to 314.51s of the 314.45s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-25.8045	 = Validation score   (-mean_absolute_error)
# 	72.74s	 = Training   runtime
# 	1.07s	 = Validation runtime
# Fitting model: NeuralNetTorch_r87_BAG_L2 ... Training model for up to 239.60s of the 239.54s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-31.5894	 = Validation score   (-mean_absolute_error)
# 	110.03s	 = Training   runtime
# 	1.67s	 = Validation runtime
# Fitting model: NeuralNetTorch_r71_BAG_L2 ... Training model for up to 126.67s of the 126.60s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	-226.0482	 = Validation score   (-mean_absolute_error)
# 	82.9s	 = Training   runtime
# 	1.63s	 = Validation runtime
# Fitting model: CatBoost_r143_BAG_L2 ... Training model for up to 40.93s of the 40.87s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with SequentialLocalFoldFittingStrategy (sequential: cpus=2, gpus=0)
# 	Ran out of time, early stopping on iteration 51.
# 	Ran out of time, early stopping on iteration 49.
# 	Ran out of time, early stopping on iteration 58.
# 	Ran out of time, early stopping on iteration 57.
# 	Ran out of time, early stopping on iteration 57.
# 	Ran out of time, early stopping on iteration 65.
# 	Ran out of time, early stopping on iteration 70.
# 	Ran out of time, early stopping on iteration 95.
# 	-26.64	 = Validation score   (-mean_absolute_error)
# 	37.2s	 = Training   runtime
# 	1.04s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 985.74s of the 1.33s of remaining time.
# 	Ensemble Weights: {'NeuralNetTorch_r22_BAG_L1': 0.217, 'LightGBM_r188_BAG_L1': 0.217, 'CatBoost_r177_BAG_L2': 0.174, 'RandomForest_r195_BAG_L2': 0.174, 'CatBoost_r137_BAG_L2': 0.13, 'NeuralNetFastAI_r191_BAG_L1': 0.087}
# 	-25.2786	 = Validation score   (-mean_absolute_error)
# 	0.14s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 29601.23s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 45.4 rows/s (333 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/kaggle/working/AutogluonModels/ag-20250912_185042")

# %%
predictor.leaderboard(silent=True).style.background_gradient(subset=['score_val'], cmap='RdYlGn')
# Out:
# <style type="text/css">
# #T_490ec_row0_col1, #T_490ec_row1_col1, #T_490ec_row2_col1, #T_490ec_row3_col1, #T_490ec_row4_col1, #T_490ec_row5_col1, #T_490ec_row6_col1, #T_490ec_row7_col1, #T_490ec_row8_col1, #T_490ec_row9_col1, #T_490ec_row10_col1, #T_490ec_row11_col1, #T_490ec_row12_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_490ec_row13_col1, #T_490ec_row14_col1, #T_490ec_row15_col1, #T_490ec_row16_col1, #T_490ec_row17_col1, #T_490ec_row18_col1, #T_490ec_row19_col1, #T_490ec_row20_col1, #T_490ec_row21_col1, #T_490ec_row22_col1, #T_490ec_row23_col1, #T_490ec_row24_col1, #T_490ec_row25_col1, #T_490ec_row26_col1, #T_490ec_row27_col1, #T_490ec_row28_col1, #T_490ec_row29_col1, #T_490ec_row30_col1, #T_490ec_row31_col1, #T_490ec_row32_col1, #T_490ec_row33_col1, #T_490ec_row34_col1, #T_490ec_row35_col1, #T_490ec_row36_col1, #T_490ec_row37_col1 {
#   background-color: #016a38;
#   color: #f1f1f1;
# }
# #T_490ec_row38_col1, #T_490ec_row39_col1, #T_490ec_row40_col1, #T_490ec_row41_col1, #T_490ec_row42_col1, #T_490ec_row43_col1, #T_490ec_row44_col1, #T_490ec_row45_col1, #T_490ec_row46_col1, #T_490ec_row47_col1, #T_490ec_row48_col1, #T_490ec_row49_col1, #T_490ec_row50_col1, #T_490ec_row51_col1, #T_490ec_row52_col1, #T_490ec_row53_col1, #T_490ec_row54_col1, #T_490ec_row55_col1 {
#   background-color: #026c39;
#   color: #f1f1f1;
# }
# #T_490ec_row56_col1, #T_490ec_row57_col1, #T_490ec_row58_col1, #T_490ec_row59_col1, #T_490ec_row60_col1 {
#   background-color: #036e3a;
#   color: #f1f1f1;
# }
# #T_490ec_row61_col1, #T_490ec_row62_col1, #T_490ec_row63_col1 {
#   background-color: #04703b;
#   color: #f1f1f1;
# }
# #T_490ec_row64_col1, #T_490ec_row65_col1, #T_490ec_row66_col1, #T_490ec_row67_col1, #T_490ec_row68_col1 {
#   background-color: #05713c;
#   color: #f1f1f1;
# }
# #T_490ec_row69_col1, #T_490ec_row70_col1, #T_490ec_row71_col1, #T_490ec_row72_col1, #T_490ec_row73_col1 {
#   background-color: #06733d;
#   color: #f1f1f1;
# }
# #T_490ec_row74_col1, #T_490ec_row75_col1, #T_490ec_row76_col1, #T_490ec_row77_col1, #T_490ec_row78_col1, #T_490ec_row79_col1 {
#   background-color: #08773f;
#   color: #f1f1f1;
# }
# #T_490ec_row80_col1, #T_490ec_row81_col1, #T_490ec_row82_col1, #T_490ec_row83_col1 {
#   background-color: #097940;
#   color: #f1f1f1;
# }
# #T_490ec_row84_col1, #T_490ec_row85_col1 {
#   background-color: #0a7b41;
#   color: #f1f1f1;
# }
# #T_490ec_row86_col1, #T_490ec_row87_col1 {
#   background-color: #0b7d42;
#   color: #f1f1f1;
# }
# #T_490ec_row88_col1 {
#   background-color: #0c7f43;
#   color: #f1f1f1;
# }
# #T_490ec_row89_col1 {
#   background-color: #0d8044;
#   color: #f1f1f1;
# }
# #T_490ec_row90_col1 {
#   background-color: #0e8245;
#   color: #f1f1f1;
# }
# #T_490ec_row91_col1 {
#   background-color: #279f53;
#   color: #f1f1f1;
# }
# #T_490ec_row92_col1 {
#   background-color: #89cc67;
#   color: #000000;
# }
# #T_490ec_row93_col1, #T_490ec_row94_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_490ec">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_490ec_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_490ec_level0_col1" class="col_heading level0 col1" >score_val</th>
#       <th id="T_490ec_level0_col2" class="col_heading level0 col2" >eval_metric</th>
#       <th id="T_490ec_level0_col3" class="col_heading level0 col3" >pred_time_val</th>
#       <th id="T_490ec_level0_col4" class="col_heading level0 col4" >fit_time</th>
#       <th id="T_490ec_level0_col5" class="col_heading level0 col5" >pred_time_val_marginal</th>
#       <th id="T_490ec_level0_col6" class="col_heading level0 col6" >fit_time_marginal</th>
#       <th id="T_490ec_level0_col7" class="col_heading level0 col7" >stack_level</th>
#       <th id="T_490ec_level0_col8" class="col_heading level0 col8" >can_infer</th>
#       <th id="T_490ec_level0_col9" class="col_heading level0 col9" >fit_order</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_490ec_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_490ec_row0_col0" class="data row0 col0" >WeightedEnsemble_L2</td>
#       <td id="T_490ec_row0_col1" class="data row0 col1" >-25.147255</td>
#       <td id="T_490ec_row0_col2" class="data row0 col2" >mean_absolute_error</td>
#       <td id="T_490ec_row0_col3" class="data row0 col3" >7.342816</td>
#       <td id="T_490ec_row0_col4" class="data row0 col4" >3678.193640</td>
#       <td id="T_490ec_row0_col5" class="data row0 col5" >0.000903</td>
#       <td id="T_490ec_row0_col6" class="data row0 col6" >0.140319</td>
#       <td id="T_490ec_row0_col7" class="data row0 col7" >2</td>
#       <td id="T_490ec_row0_col8" class="data row0 col8" >True</td>
#       <td id="T_490ec_row0_col9" class="data row0 col9" >24</td>
#     </tr>
#     <tr>
#       <th id="T_490ec_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_490ec_row1_col0" class="data row1 col0" >WeightedEnsemble_L3</td>
#       <td id="T_490ec_row1_col1" class="data row1 col1" >-25.278599</td>
#       <td id="T_490ec_row1_col2" class="data row1 col2" >mean_absolute_error</td>
#       <td id="T_490ec_row1_col3" class="data row1 col3" >32.114326</td>
#       <td id="T_490ec_row1_col4" class="data row1 col4" >11184.817340</td>
#       <td id="T_490ec_row1_col5" class="data row1 col5" >0.000937</td>
#       <td id="T_490ec_row1_col6" class="data row1 col6" >0.140702</td>
#       <td id="T_490ec_row1_col7" class="data row1 col7" >3</td>
#       <td id="T_490ec_row1_col8" class="data row1 col8" >True</td>
#       <td id="T_490ec_row1_col9" class="data row1 col9" >95</td>
#     </tr>
#     <tr>
#       <th id="T_490ec_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_490ec_row2_col0" class="data row2 col0" >CatBoost_r137_BAG_L2</td>
#       <td id="T_490ec_row2_col1" class="data row2 col1" >-25.746891</td>
#       <td id="T_490ec_row2_col2" class="data row2 col2" >mean_absolute_error</td>
#       <td id="T_490ec_row2_col3" class="data row2 col3" >28.922395</td>
#       <td id="T_490ec_row2_col4" class="data row2 col4" >10939.342999</td>
#       <td id="T_490ec_row2_col5" class="data row2 col5" >1.035213</td>
#       <td id="T_490ec_row2_col6" class="data row2 col6" >71.426116</td>
#       <td id="T_490ec_row2_col7" class="data row2 col7" >2</td>
#       <td id="T_490ec_row2_col8" class="data row2 col8" >True</td>
#       <td id="T_490ec_row2_col9" class="data row2 col9" >43</td>
#     </tr>
#     <tr>
#       <th id="T_490ec_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_490ec_row3_col0" class="data row3 col0" >CatBoost_r177_BAG_L2</td>
#       <td id="T_490ec_row3_col1" class="data row3 col1" >-25.757385</td>
#       <td id="T_490ec_row3_col2" class="data row3 col2" >mean_absolute_error</td>
#       <td id="T_490ec_row3_col3" class="data row3 col3" >28.620142</td>
#       <td id="T_490ec_row3_col4" class="data row3 col4" >10999.911353</td>
#       <td id="T_490ec_row3_col5" class="data row3 col5" >0.732960</td>
#       <td id="T_490ec_row3_col6" class="data row3 col6" >131.994470</td>
#       <td id="T_490ec_row3_col7" class="data row3 col7" >2</td>
#       <td id="T_490ec_row3_col8" class="data row3 col8" >True</td>
#       <td id="T_490ec_row3_col9" class="data row3 col9" >34</td>
#     </tr>
#     <tr>
#       <th id="T_490ec_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_490ec_row4_col0" class="data row4 col0" >CatBoost_r5_BAG_L2</td>
#       <td id="T_490ec_row4_col1" class="data row4 col1" >-25.804502</td>
#       <td id="T_490ec_row4_col2" class="data row4 col2" >mean_absolute_error</td>
#       <td id="T_490ec_row4_col3" class="data row4 col3" >28.961172</td>
#       <td id="T_490ec_row4_col4" class="data row4 col4" >10940.655030</td>
#       <td id="T_490ec_row4_col5" class="data row4 col5" >1.073990</td>
#       <td id="T_490ec_row4_col6" class="data row4 col6" >72.738147</td>
#       <td id="T_490ec_row4_col7" class="data row4 col7" >2</td>
#       <td id="T_490ec_row4_col8" class="data row4 col8" >True</td>
#       <td id="T_490ec_row4_col9" class="data row4 col9" >91</td>
#     </tr>
#     <tr>
#       <th id="T_490ec_level0_row5" class="row_heading level0 row5" >5</

# %%
print("\nGenerating test predictions...")
test_preds = predictor.predict(test_ag)
# Out:
# Generating test predictions...

# %% [markdown]
# <!-- ================= H2 HEADER: Submission File Creation ================= -->
# <div style="border-radius:25px 70px; padding:14px 18px; margin:10px 0;
#             font-family:'Quicksand', sans-serif; background:#24a695; overflow:hidden;">
#   <div style="text-align:center; color:#ffffff; font-size:150%; margin:0; padding:0;">
#     <b><h2 style="margin:0; color:#ffffff;">Submission File Creation</h2></b>
#   </div>
# </div>
#
# <!-- ================= BADGES: Submission Steps ================= -->
# <div style="display:flex; gap:10px; flex-wrap:wrap; justify-content:center; margin:12px 0; font-family:Inter, system-ui, 'Segoe UI', Roboto, Arial, sans-serif;">
#   <span style="background:#e2e8f0; color:#0f172a; padding:6px 14px; border-radius:999px; font-size:13px; border:1px solid #cbd5e1;">Prepare Submission DataFrame</span>
#   <span style="background:#dbeafe; color:#1e3a8a; padding:6px 14px; border-radius:999px; font-size:13px; border:1px solid #bfdbfe;">Save CSV File</span>
#
#
# </div>

# %%
submission = sample_submission.copy()
submission[TARGET] = test_preds
submission.to_csv("submission.csv", index=False)
print("\nSubmission file 'submission.csv' created successfully.")

# End timing the script
end_time = time.time()
print(f"\nTotal script execution time: {end_time - start_time:.2f} seconds")

submission.head()
# Out:
# Submission file 'submission.csv' created successfully.
#
# Total script execution time: 39696.87 seconds
#      id          Tm
# 0  1022  350.845123
# 1  1146  326.353333
# 2    79  199.928406
# 3  2279  208.856689
# 4  1342  228.116394

# %%
shutil.rmtree("AutogluonModels")

# %% [markdown]
# <!-- ================= HEADER + BADGES MERGED ================= -->
# <div style="border-radius:25px 70px; padding:14px 18px; margin:0 0 18px 0; font-family:'Quicksand', sans-serif; background:#24a695; overflow:hidden;">
#   <div style="text-align:center; color:#ffffff; font-size:170%; margin:0; padding:0;">
#     <b><h3 style="text-align:center; color:#ffffff; font-size:150%; margin:0; padding:0;">Thank You</h3></b>
#   </div>
# </div>
#
# <div style="display:flex; gap:8px; flex-wrap:wrap; margin-top:10px; font-family:Inter, system-ui, 'Segoe UI', Roboto, Arial, sans-serif;">
#   <a href="#Thermophysical-Property:-Melting-Point" style="margin-left:auto; font-size:12px; color:red; text-decoration:none;">Back to top ↑</a>
# </div>
